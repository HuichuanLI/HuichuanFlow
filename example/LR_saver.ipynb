# %%
import sys

sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import HuichuanFlow as hf

from HuichuanFlow.trainer import SimpleTrainer

# %%
from sklearn.datasets import make_circles

# 获取同心圆状分布的数据，X的每行包含两个特征，y是1/0类别标签
X, y = make_circles(200, noise=0.1, factor=0.2)
y = y * 2 - 1  # 将标签转化为1/-1

# 是否使用二次项
use_quadratic = False

# 一次项，2维向量（2x1矩阵）
x1 = hf.core.Variable(dim=(2, 1), init=False, trainable=False)

# 标签
label = hf.core.Variable(dim=(1, 1), init=False, trainable=False)

# 偏置
b = hf.core.Variable(dim=(1, 1), init=True, trainable=True)

# 根据是否使用二次项区别处理
if use_quadratic:

    # 将一次项与自己的转置相乘，得到二次项2x2矩阵，再转成4维向量（4x1矩阵）
    x2 = hf.ops.Reshape(
            hf.ops.MatMul(x1, hf.ops.Reshape(x1, shape=(1, 2))),
            shape=(4, 1)
            )

    # 将一次和二次项连接成6维向量（6x1矩阵）
    x = hf.ops.Concat(x1, x2)
    
    # 权值向量是6维（1x6矩阵）
    w = hf.core.Variable(dim=(1, 6), init=True, trainable=True)
    
else:
    
    # 特征向量就是一次项
    x = x1
    
    # 权值向量是2维（1x2矩阵）
    w = hf.core.Variable(dim=(1, 2), init=True, trainable=True)

# %%
# 线性部分
output = hf.ops.Add(hf.ops.MatMul(w, x), b)

# 预测概率
predict = hf.ops.Logistic(output)

# 损失函数
loss = hf.ops.loss.LogLoss(hf.ops.MatMul(label, output))

learning_rate = 0.001

optimizer = hf.optimizer.Adam(hf.default_graph, loss, learning_rate)
accuracy = hf.ops.metrics.Accuracy(predict, label)
precision = hf.ops.metrics.Precision(predict, label)
recall = hf.ops.metrics.Recall(predict, label)
auc = hf.ops.metrics.ROC_AUC(predict, label)

batch_size = 8

# %%
batch_size = 16

trainer = SimpleTrainer([x1], label,
                        loss, optimizer, epoches=20, batch=16,eval_on_train=True,metrics_ops=[accuracy,precision,recall,auc])
train_inputs = {x1.name: X}
trainer.train_and_eval(train_inputs, y, train_inputs, y)
# Out:
# [INIT] Variable weights init finished
# - Epoch [1] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.04  and loss value: 0.692835
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692779
# - Epoch [1] train finished, time cost: 0.07
# Epoch [1] evaluation metrics Accuracy: 0.3800 Precision: 0.3065 Recall: 0.1900 ROC_AUC: 0.5093
# - Epoch [2] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.04  and loss value: 0.693184
# -- iteration [199] finished, time cost: 0.04  and loss value: 0.693265
# - Epoch [2] train finished, time cost: 0.07
# Epoch [2] evaluation metrics Accuracy: 0.3150 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.5053
# - Epoch [3] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.693465
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693682
# - Epoch [3] train finished, time cost: 0.06
# Epoch [3] evaluation metrics Accuracy: 0.3200 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.5023
# - Epoch [4] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.693619
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693972
# - Epoch [4] train finished, time cost: 0.06
# Epoch [4] evaluation metrics Accuracy: 0.3250 Precision: 0.0270 Recall: 0.0100 ROC_AUC: 0.5017
# - Epoch [5] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.693616
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.694105
# - Epoch [5] train finished, time cost: 0.06
# Epoch [5] evaluation metrics Accuracy: 0.3150 Precision: 0.1064 Recall: 0.0500 ROC_AUC: 0.5019
# - Epoch [6] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.693460
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.694083
# - Epoch [6] train finished, time cost: 0.06
# Epoch [6] evaluation metrics Accuracy: 0.3450 Precision: 0.2281 Recall: 0.1300 ROC_AUC: 0.5014
# - Epoch [7] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.693175
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693933
# - Epoch [7] train finished, time cost: 0.06
# Epoch [7] evaluation metrics Accuracy: 0.4100 Precision: 0.3750 Recall: 0.2700 ROC_AUC: 0.5023
# - Epoch [8] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.692797
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693689
# - Epoch [8] train finished, time cost: 0.07
# Epoch [8] evaluation metrics Accuracy: 0.4550 Precision: 0.4505 Recall: 0.4100 ROC_AUC: 0.5020
# - Epoch [9] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.692365
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693390
# - Epoch [9] train finished, time cost: 0.06
# Epoch [9] evaluation metrics Accuracy: 0.5150 Precision: 0.5143 Recall: 0.5400 ROC_AUC: 0.5021
# - Epoch [10] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.691919
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693077
# - Epoch [10] train finished, time cost: 0.06
# Epoch [10] evaluation metrics Accuracy: 0.5500 Precision: 0.5439 Recall: 0.6200 ROC_AUC: 0.5013
# - Epoch [11] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.691498
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692788
# - Epoch [11] train finished, time cost: 0.06
# Epoch [11] evaluation metrics Accuracy: 0.5600 Precision: 0.5517 Recall: 0.6400 ROC_AUC: 0.5013
# - Epoch [12] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.691135
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692556
# - Epoch [12] train finished, time cost: 0.06
# Epoch [12] evaluation metrics Accuracy: 0.5650 Precision: 0.5546 Recall: 0.6600 ROC_AUC: 0.5018
# - Epoch [13] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690854
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692406
# - Epoch [13] train finished, time cost: 0.06
# Epoch [13] evaluation metrics Accuracy: 0.5650 Precision: 0.5546 Recall: 0.6600 ROC_AUC: 0.5015
# - Epoch [14] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690665
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692346
# - Epoch [14] train finished, time cost: 0.06
# Epoch [14] evaluation metrics Accuracy: 0.5550 Precision: 0.5470 Recall: 0.6400 ROC_AUC: 0.5017
# - Epoch [15] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690563
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692373
# - Epoch [15] train finished, time cost: 0.06
# Epoch [15] evaluation metrics Accuracy: 0.5550 Precision: 0.5478 Recall: 0.6300 ROC_AUC: 0.5016
# - Epoch [16] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690535
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692473
# - Epoch [16] train finished, time cost: 0.06
# Epoch [16] evaluation metrics Accuracy: 0.5450 Precision: 0.5398 Recall: 0.6100 ROC_AUC: 0.5019
# - Epoch [17] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690559
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692625
# - Epoch [17] train finished, time cost: 0.06
# Epoch [17] evaluation metrics Accuracy: 0.5400 Precision: 0.5357 Recall: 0.6000 ROC_AUC: 0.5017
# - Epoch [18] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690611
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692805
# - Epoch [18] train finished, time cost: 0.06
# Epoch [18] evaluation metrics Accuracy: 0.5100 Precision: 0.5094 Recall: 0.5400 ROC_AUC: 0.5021
# - Epoch [19] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690666
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.692986
# - Epoch [19] train finished, time cost: 0.06
# Epoch [19] evaluation metrics Accuracy: 0.4900 Precision: 0.4902 Recall: 0.5000 ROC_AUC: 0.5021
# - Epoch [20] train start, batch size: 8, train data size: 1
# -- iteration [99] finished, time cost: 0.03  and loss value: 0.690701
# -- iteration [199] finished, time cost: 0.03  and loss value: 0.693146
# - Epoch [20] train finished, time cost: 0.06
# Epoch [20] evaluation metrics Accuracy: 0.4700 Precision: 0.4694 Recall: 0.4600 ROC_AUC: 0.5024

# %%
from HuichuanFlow_serving.exporter import Exporter

exporter = Exporter()
sig = exporter.signature('Variable:0', 'Logistic:6')

# %%
saver = hf.trainer.Saver('./epoches20')
saver.save(model_file_name='my_model.json',
           weights_file_name='my_weights.npz',service_signature=sig)
# Out:
# Save model into file: ./epoches20/my_model.json
# Save weights to file: ./epoches20/my_weights.npz
