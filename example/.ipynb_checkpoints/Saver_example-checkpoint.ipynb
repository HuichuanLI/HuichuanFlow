# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import HuichuanFlow as ms
from HuichuanFlow.trainer import SimpleTrainer

# 读取数据，去掉无用列
data = pd.read_csv("../data/titanic.csv").drop(["PassengerId", 
                  "Name", "Ticket", "Cabin"], axis=1)

# 构造编码类
le = LabelEncoder()
ohe = OneHotEncoder(sparse=False)

# 对类别型特征做One-Hot编码
Pclass = ohe.fit_transform(le.fit_transform(data["Pclass"].fillna(0)).reshape(-1, 1))
Sex = ohe.fit_transform(le.fit_transform(data["Sex"].fillna("")).reshape(-1, 1))
Embarked = ohe.fit_transform(le.fit_transform(data["Embarked"].fillna("")).reshape(-1, 1))

# 组合特征列
features = np.concatenate([Pclass,
                           Sex,
                           data[["Age"]].fillna(0),
                           data[["SibSp"]].fillna(0),
                           data[["Parch"]].fillna(0),
                           data[["Fare"]].fillna(0),
                           Embarked
                           ], axis=1)

# 标签
labels = data["Survived"].values * 2 - 1

# 特征维数
dimension = features.shape[1]

# 嵌入向量维度
k = 2

# 一次项
x = ms.core.Variable(dim=(dimension, 1), init=False, trainable=False)

# 三个类别类特征的三套One-Hot
x_Pclass = ms.core.Variable(dim=(Pclass.shape[1], 1), init=False, trainable=False)
x_Sex = ms.core.Variable(dim=(Sex.shape[1], 1), init=False, trainable=False)
x_Embarked = ms.core.Variable(dim=(Embarked.shape[1], 1), init=False, trainable=False)


# 标签
label = ms.core.Variable(dim=(1, 1), init=False, trainable=False)

# 一次项权值向量
w = ms.core.Variable(dim=(1, dimension), init=True, trainable=True)

# 类别类特征的嵌入矩阵
E_Pclass = ms.core.Variable(dim=(k, Pclass.shape[1]), init=True, trainable=True)
E_Sex = ms.core.Variable(dim=(k, Sex.shape[1]), init=True, trainable=True)
E_Embarked = ms.core.Variable(dim=(k, Embarked.shape[1]), init=True, trainable=True)

# 偏置
b = ms.core.Variable(dim=(1, 1), init=True, trainable=True)


# Wide部分
wide = ms.ops.MatMul(w, x)


# Deep部分，三个嵌入向量
embedding_Pclass = ms.ops.MatMul(E_Pclass, x_Pclass)
embedding_Sex = ms.ops.MatMul(E_Sex, x_Sex)
embedding_Embarked = ms.ops.MatMul(E_Embarked, x_Embarked)

# 将三个嵌入向量连接在一起
embedding = ms.ops.Concat(
        embedding_Pclass,
        embedding_Sex,
        embedding_Embarked
        )

# 第一隐藏层
hidden_1 = ms.layer.fc(embedding, 3 * k, 8, "ReLU")

# 第二隐藏层
hidden_2 = ms.layer.fc(hidden_1, 8, 4, "ReLU")

# 输出层
deep = ms.layer.fc(hidden_2, 4, 1, None)

# 输出
output = ms.ops.Add(wide, deep, b)

# 预测概率
predict = ms.ops.Logistic(output)

# 损失函数
loss = ms.ops.loss.LogLoss(ms.ops.Multiply(label, output))

learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)
accuracy = ms.ops.metrics.Accuracy(output, label)
precision = ms.ops.metrics.Precision(output, label)
recall = ms.ops.metrics.Recall(output, label)
auc = ms.ops.metrics.ROC_AUC(output, label)
roc = ms.ops.metrics.ROC(output, label)

batch_size = 16

trainer = SimpleTrainer([x, x_Pclass, x_Sex, x_Embarked], label,
                        loss, optimizer, epoches=20, batch=16,eval_on_train=True,metrics_ops=[accuracy,precision,recall,auc])
train_inputs = {
    x.name: features,
    x_Pclass.name: features[:, :3],
    x_Sex.name: features[:, 3:5],
    x_Embarked.name: features[:, 9:]
}

trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
# Out:
# [INIT] Variable weights init finished
# - Epoch [1] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.659642
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.669629
# -- iteration [299] finished, time cost: 0.12  and loss value: 1.825668
# -- iteration [399] finished, time cost: 0.10  and loss value: 0.839026
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.523250
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.321726
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.385233
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.401682
# - Epoch [1] train finished, time cost: 1.03
# Epoch [1] evaluation metrics Accuracy: 0.6162 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.4325
# - Epoch [2] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.349593
# -- iteration [199] finished, time cost: 0.10  and loss value: 0.455590
# -- iteration [299] finished, time cost: 0.11  and loss value: 2.329221
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.082305
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.412407
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.508297
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.284579
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.386136
# - Epoch [2] train finished, time cost: 1.02
# Epoch [2] evaluation metrics Accuracy: 0.6330 Precision: 0.7778 Recall: 0.0614 ROC_AUC: 0.6328
# - Epoch [3] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.380457
# -- iteration [199] finished, time cost: 0.10  and loss value: 0.470377
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.193199
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.020598
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.409553
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.968662
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.275939
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.488636
# - Epoch [3] train finished, time cost: 1.05
# Epoch [3] evaluation metrics Accuracy: 0.6700 Precision: 0.6765 Recall: 0.2690 ROC_AUC: 0.6975
# - Epoch [4] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.483314
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.539038
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.009442
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.931367
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.405005
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.685131
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.259553
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.532370
# - Epoch [4] train finished, time cost: 1.11
# Epoch [4] evaluation metrics Accuracy: 0.6869 Precision: 0.6886 Recall: 0.3363 ROC_AUC: 0.7085
# - Epoch [5] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.14  and loss value: 0.504182
# -- iteration [199] finished, time cost: 0.15  and loss value: 0.558593
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.004418
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.931777
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.370710
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.718359
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.223185
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.480200
# - Epoch [5] train finished, time cost: 1.08
# Epoch [5] evaluation metrics Accuracy: 0.6700 Precision: 0.6667 Recall: 0.2807 ROC_AUC: 0.7097
# - Epoch [6] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.438315
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.526557
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.011603
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.994281
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.326907
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.943641
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.189848
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.398881
# - Epoch [6] train finished, time cost: 1.07
# Epoch [6] evaluation metrics Accuracy: 0.6700 Precision: 0.7449 Recall: 0.2135 ROC_AUC: 0.7084
# - Epoch [7] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.363414
# -- iteration [199] finished, time cost: 0.15  and loss value: 0.488875
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.050194
# -- iteration [399] finished, time cost: 0.13  and loss value: 1.047141
# -- iteration [499] finished, time cost: 0.15  and loss value: 0.299490
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.181707
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.178519
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.352546
# - Epoch [7] train finished, time cost: 1.15
# Epoch [7] evaluation metrics Accuracy: 0.6577 Precision: 0.7937 Recall: 0.1462 ROC_AUC: 0.7109
# - Epoch [8] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.334544
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.486502
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.119446
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.024714
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.300245
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.223142
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.194928
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.362016
# - Epoch [8] train finished, time cost: 1.05
# Epoch [8] evaluation metrics Accuracy: 0.6599 Precision: 0.8197 Recall: 0.1462 ROC_AUC: 0.7340
# - Epoch [9] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.363320
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.533190
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.113218
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.924562
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.324563
# -- iteration [599] finished, time cost: 0.12  and loss value: 1.058624
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.233423
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.414263
# - Epoch [9] train finished, time cost: 1.06
# Epoch [9] evaluation metrics Accuracy: 0.6734 Precision: 0.8493 Recall: 0.1813 ROC_AUC: 0.7677
# - Epoch [10] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.15  and loss value: 0.429145
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.610988
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.071704
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.808444
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.353643
# -- iteration [599] finished, time cost: 0.14  and loss value: 0.874265
# -- iteration [699] finished, time cost: 0.16  and loss value: 0.273873
# -- iteration [799] finished, time cost: 0.16  and loss value: 0.469069
# - Epoch [10] train finished, time cost: 1.25
# Epoch [10] evaluation metrics Accuracy: 0.6846 Precision: 0.8427 Recall: 0.2193 ROC_AUC: 0.7923
# - Epoch [11] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.14  and loss value: 0.484551
# -- iteration [199] finished, time cost: 0.14  and loss value: 0.678987
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.061016
# -- iteration [399] finished, time cost: 0.14  and loss value: 0.733274
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.366676
# -- iteration [599] finished, time cost: 0.15  and loss value: 0.801382
# -- iteration [699] finished, time cost: 0.16  and loss value: 0.292969
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.487644
# - Epoch [11] train finished, time cost: 1.28
# Epoch [11] evaluation metrics Accuracy: 0.6824 Precision: 0.8554 Recall: 0.2076 ROC_AUC: 0.8064
# - Epoch [12] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.15  and loss value: 0.494306
# -- iteration [199] finished, time cost: 0.14  and loss value: 0.708669
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.084468
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.708765
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.359338
# -- iteration [599] finished, time cost: 0.15  and loss value: 0.835247
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.288332
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.472165
# - Epoch [12] train finished, time cost: 1.23
# Epoch [12] evaluation metrics Accuracy: 0.6712 Precision: 0.8451 Recall: 0.1754 ROC_AUC: 0.8141
# - Epoch [13] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.472253
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.709465
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.130824
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.709869
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.344025
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.894960
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.276118
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.454313
# - Epoch [13] train finished, time cost: 1.16
# Epoch [13] evaluation metrics Accuracy: 0.6689 Precision: 0.8406 Recall: 0.1696 ROC_AUC: 0.8176
# - Epoch [14] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.454134
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.709651
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.145196
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.706709
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.332451
# -- iteration [599] finished, time cost: 0.17  and loss value: 0.901786
# -- iteration [699] finished, time cost: 0.17  and loss value: 0.267936
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.453572
# - Epoch [14] train finished, time cost: 1.27
# Epoch [14] evaluation metrics Accuracy: 0.6734 Precision: 0.8493 Recall: 0.1813 ROC_AUC: 0.8195
# - Epoch [15] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.453713
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.722245
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.111854
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.692033
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.324917
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.862360
# -- iteration [699] finished, time cost: 0.14  and loss value: 0.262003
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.462265
# - Epoch [15] train finished, time cost: 1.16
# Epoch [15] evaluation metrics Accuracy: 0.6824 Precision: 0.8642 Recall: 0.2047 ROC_AUC: 0.8200
# - Epoch [16] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.457904
# -- iteration [199] finished, time cost: 0.14  and loss value: 0.737712
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.082129
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.678959
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.315734
# -- iteration [599] finished, time cost: 0.15  and loss value: 0.834871
# -- iteration [699] finished, time cost: 0.15  and loss value: 0.252485
# -- iteration [799] finished, time cost: 0.15  and loss value: 0.463971
# - Epoch [16] train finished, time cost: 1.23
# Epoch [16] evaluation metrics Accuracy: 0.6902 Precision: 0.8750 Recall: 0.2251 ROC_AUC: 0.8205
# - Epoch [17] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.451466
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.743832
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.073527
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.676675
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.302872
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.845063
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.239324
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.454939
# - Epoch [17] train finished, time cost: 1.15
# Epoch [17] evaluation metrics Accuracy: 0.6891 Precision: 0.8736 Recall: 0.2222 ROC_AUC: 0.8220
# - Epoch [18] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.435383
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.741663
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.077665
# -- iteration [399] finished, time cost: 0.14  and loss value: 0.680272
# -- iteration [499] finished, time cost: 0.15  and loss value: 0.289730
# -- iteration [599] finished, time cost: 0.15  and loss value: 0.872673
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.227555
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.444689
# - Epoch [18] train finished, time cost: 1.19
# Epoch [18] evaluation metrics Accuracy: 0.6869 Precision: 0.8706 Recall: 0.2164 ROC_AUC: 0.8233
# - Epoch [19] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.14  and loss value: 0.421296
# -- iteration [199] finished, time cost: 0.14  and loss value: 0.741631
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.081503
# -- iteration [399] finished, time cost: 0.15  and loss value: 0.678822
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.280254
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.884813
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.220985
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.442340
# - Epoch [19] train finished, time cost: 1.21
# Epoch [19] evaluation metrics Accuracy: 0.6914 Precision: 0.8764 Recall: 0.2281 ROC_AUC: 0.8256
# - Epoch [20] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.416536
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.750815
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.077715
# -- iteration [399] finished, time cost: 0.14  and loss value: 0.667569
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.274974
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.872319
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.219017
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.447840
# - Epoch [20] train finished, time cost: 1.10
# Epoch [20] evaluation metrics Accuracy: 0.6958 Precision: 0.8817 Recall: 0.2398 ROC_AUC: 0.8276
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95cfa7b690a7> in <module>
#     120 saver = ms.trainer.Saver('./epoches10')
#     121 saver.save(model_file_name='my_model.json',
# --> 122            weights_file_name='my_weights.npz', service_signature=sig)
#
# NameError: name 'sig' is not defined

# %%
saver = ms.trainer.Saver('./epoches10')
saver.save(model_file_name='my_model.json',
           weights_file_name='my_weights.npz')
