# %%
import sys
sys.path.append('../')

import numpy as np
from sklearn.datasets import make_classification
import HuichuanFlow as ms

# 特征维数
dimension = 60

# 构造二分类样本，有用特征占20维
X, y = make_classification(600, dimension, n_informative=20)
y = y * 2 - 1


# 嵌入向量维度
k = 20

# 一次项
x1 = ms.core.Variable(dim=(dimension, 1), init=False, trainable=False)

# 标签
label = ms.core.Variable(dim=(1, 1), init=False, trainable=False)

# 一次项权值向量
w = ms.core.Variable(dim=(1, dimension), init=True, trainable=True)

# 嵌入矩阵
E = ms.core.Variable(dim=(k, dimension), init=True, trainable=True)

# 偏置
b = ms.core.Variable(dim=(1, 1), init=True, trainable=True)


# Wide部分
wide = ms.ops.MatMul(w, x1)


# Deep部分
embedding = ms.ops.MatMul(E, x1)  # 用嵌入矩阵与特征向量相乘，得到嵌入向量

# 第一隐藏层
hidden_1 = ms.layer.fc(embedding, k, 8, "ReLU")

# 第二隐藏层
hidden_2 = ms.layer.fc(hidden_1, 8, 4, "ReLU")

# 输出层
deep = ms.layer.fc(hidden_2, 4, 1, None)

# 输出
output = ms.ops.Add(wide, deep, b)

# 预测概率
predict = ms.ops.Logistic(output)

# 损失函数
loss = ms.ops.loss.LogLoss(ms.ops.MatMul(label, output))

learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)


batch_size = 16

for epoch in range(200):
    
    batch_count = 0   
    for i in range(len(X)):
        
        x1.set_value(np.mat(X[i]).T)
        label.set_value(np.mat(y[i]))
        
        optimizer.one_step()
        
        batch_count += 1
        if batch_count >= batch_size:
            
            optimizer.update()
            batch_count = 0
        

    pred = []
    for i in range(len(X)):
                
        x1.set_value(np.mat(X[i]).T)
        
        predict.forward()
        pred.append(predict.value[0, 0])
            
    pred = (np.array(pred) > 0.5).astype(np.int) * 2 - 1
    accuracy = (y == pred).astype(np.int).sum() / len(X)
       
    print("epoch: {:d}, accuracy: {:.3f}".format(epoch + 1, accuracy))
# Out:
# epoch: 1, accuracy: 0.797
# epoch: 2, accuracy: 0.800
# epoch: 3, accuracy: 0.815
# epoch: 4, accuracy: 0.823
# epoch: 5, accuracy: 0.827
# epoch: 6, accuracy: 0.835
# epoch: 7, accuracy: 0.835
# epoch: 8, accuracy: 0.830
# epoch: 9, accuracy: 0.830
# epoch: 10, accuracy: 0.832
# epoch: 11, accuracy: 0.833
# epoch: 12, accuracy: 0.835
# epoch: 13, accuracy: 0.838
# epoch: 14, accuracy: 0.837
# epoch: 15, accuracy: 0.837
# epoch: 16, accuracy: 0.838
# epoch: 17, accuracy: 0.837
# epoch: 18, accuracy: 0.837
# epoch: 19, accuracy: 0.840
# epoch: 20, accuracy: 0.840
# epoch: 21, accuracy: 0.840
# epoch: 22, accuracy: 0.840
# epoch: 23, accuracy: 0.840
# epoch: 24, accuracy: 0.840
# epoch: 25, accuracy: 0.840
# epoch: 26, accuracy: 0.840
# epoch: 27, accuracy: 0.840
# epoch: 28, accuracy: 0.840
# epoch: 29, accuracy: 0.840
# epoch: 30, accuracy: 0.840
# epoch: 31, accuracy: 0.840
# epoch: 32, accuracy: 0.838
# epoch: 33, accuracy: 0.838
# epoch: 34, accuracy: 0.838
# epoch: 35, accuracy: 0.838
# epoch: 36, accuracy: 0.838
# epoch: 37, accuracy: 0.840
# epoch: 38, accuracy: 0.840
# epoch: 39, accuracy: 0.840
# epoch: 40, accuracy: 0.840
# epoch: 41, accuracy: 0.840
# epoch: 42, accuracy: 0.842
# epoch: 43, accuracy: 0.842
# epoch: 44, accuracy: 0.842
# epoch: 45, accuracy: 0.842
# epoch: 46, accuracy: 0.842
# epoch: 47, accuracy: 0.842
# epoch: 48, accuracy: 0.842
# epoch: 49, accuracy: 0.842
# epoch: 50, accuracy: 0.842
# epoch: 51, accuracy: 0.842
# epoch: 52, accuracy: 0.842
# epoch: 53, accuracy: 0.842
# epoch: 54, accuracy: 0.842
# epoch: 55, accuracy: 0.842
# epoch: 56, accuracy: 0.842
# epoch: 57, accuracy: 0.842
# epoch: 58, accuracy: 0.842
# epoch: 59, accuracy: 0.842
# epoch: 60, accuracy: 0.842
# epoch: 61, accuracy: 0.842
# epoch: 62, accuracy: 0.842
# epoch: 63, accuracy: 0.842
# epoch: 64, accuracy: 0.842
# epoch: 65, accuracy: 0.842
# epoch: 66, accuracy: 0.842
# epoch: 67, accuracy: 0.842
# epoch: 68, accuracy: 0.842
# epoch: 69, accuracy: 0.842
# epoch: 70, accuracy: 0.842
# epoch: 71, accuracy: 0.842
# epoch: 72, accuracy: 0.842
# epoch: 73, accuracy: 0.842
# epoch: 74, accuracy: 0.842
# epoch: 75, accuracy: 0.842
# epoch: 76, accuracy: 0.842
# epoch: 77, accuracy: 0.842
# epoch: 78, accuracy: 0.842
# epoch: 79, accuracy: 0.842
# epoch: 80, accuracy: 0.842
# epoch: 81, accuracy: 0.842
# epoch: 82, accuracy: 0.842
# epoch: 83, accuracy: 0.842
# epoch: 84, accuracy: 0.842
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-04bec41c0408> in <module>
#      84     for i in range(len(X)):
#      85
# ---> 86         x1.set_value(np.mat(X[i]).T)
#      87
#      88         predict.forward()
#
# KeyboardInterrupt:
