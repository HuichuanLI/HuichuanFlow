# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import HuichuanFlow as ms
from HuichuanFlow.trainer import SimpleTrainer

# 读取数据，去掉无用列
data = pd.read_csv("../data/titanic.csv").drop(["PassengerId", 
                  "Name", "Ticket", "Cabin"], axis=1)

# 构造编码类
le = LabelEncoder()
ohe = OneHotEncoder(sparse=False)

# 对类别型特征做One-Hot编码
Pclass = ohe.fit_transform(le.fit_transform(data["Pclass"].fillna(0)).reshape(-1, 1))
Sex = ohe.fit_transform(le.fit_transform(data["Sex"].fillna("")).reshape(-1, 1))
Embarked = ohe.fit_transform(le.fit_transform(data["Embarked"].fillna("")).reshape(-1, 1))

# 组合特征列
features = np.concatenate([Pclass,
                           Sex,
                           data[["Age"]].fillna(0),
                           data[["SibSp"]].fillna(0),
                           data[["Parch"]].fillna(0),
                           data[["Fare"]].fillna(0),
                           Embarked
                           ], axis=1)

# 标签
labels = data["Survived"].values * 2 - 1

# 特征维数
dimension = features.shape[1]

# 嵌入向量维度
k = 2

# 一次项
x = ms.core.Variable(dim=(dimension, 1), init=False, trainable=False)

# 三个类别类特征的三套One-Hot
x_Pclass = ms.core.Variable(dim=(Pclass.shape[1], 1), init=False, trainable=False)
x_Sex = ms.core.Variable(dim=(Sex.shape[1], 1), init=False, trainable=False)
x_Embarked = ms.core.Variable(dim=(Embarked.shape[1], 1), init=False, trainable=False)


# 标签
label = ms.core.Variable(dim=(1, 1), init=False, trainable=False)

# 一次项权值向量
w = ms.core.Variable(dim=(1, dimension), init=True, trainable=True)

# 类别类特征的嵌入矩阵
E_Pclass = ms.core.Variable(dim=(k, Pclass.shape[1]), init=True, trainable=True)
E_Sex = ms.core.Variable(dim=(k, Sex.shape[1]), init=True, trainable=True)
E_Embarked = ms.core.Variable(dim=(k, Embarked.shape[1]), init=True, trainable=True)

# 偏置
b = ms.core.Variable(dim=(1, 1), init=True, trainable=True)


# Wide部分
wide = ms.ops.MatMul(w, x)


# Deep部分，三个嵌入向量
embedding_Pclass = ms.ops.MatMul(E_Pclass, x_Pclass)
embedding_Sex = ms.ops.MatMul(E_Sex, x_Sex)
embedding_Embarked = ms.ops.MatMul(E_Embarked, x_Embarked)

# 将三个嵌入向量连接在一起
embedding = ms.ops.Concat(
        embedding_Pclass,
        embedding_Sex,
        embedding_Embarked
        )

# 第一隐藏层
hidden_1 = ms.layer.fc(embedding, 3 * k, 8, "ReLU")

# 第二隐藏层
hidden_2 = ms.layer.fc(hidden_1, 8, 4, "ReLU")

# 输出层
deep = ms.layer.fc(hidden_2, 4, 1, None)

# 输出
output = ms.ops.Add(wide, deep, b)

# 预测概率
predict = ms.ops.Logistic(output)

# 损失函数
loss = ms.ops.loss.LogLoss(ms.ops.Multiply(label, output))

learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)
accuracy = ms.ops.metrics.Accuracy(output, label)
precision = ms.ops.metrics.Precision(output, label)
recall = ms.ops.metrics.Recall(output, label)
auc = ms.ops.metrics.ROC_AUC(output, label)
roc = ms.ops.metrics.ROC(output, label)

batch_size = 16

trainer = SimpleTrainer([x, x_Pclass, x_Sex, x_Embarked], label,
                        loss, optimizer, epoches=20, batch=16,eval_on_train=True,metrics_ops=[accuracy,precision,recall,auc])
train_inputs = {
    x.name: features,
    x_Pclass.name: features[:, :3],
    x_Sex.name: features[:, 3:5],
    x_Embarked.name: features[:, 9:]
}

trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
saver = ms.trainer.Saver('./epoches10')
saver.save(model_file_name='my_model.json',
           weights_file_name='my_weights.npz', service_signature=sig)
# Out:
# [INIT] Variable weights init finished
# - Epoch [1] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.665985
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.678033
# -- iteration [299] finished, time cost: 0.12  and loss value: 1.987150
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.826685
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.532793
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.308751
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.399683
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.412610
# - Epoch [1] train finished, time cost: 1.03
# Epoch [1] evaluation metrics Accuracy: 0.6162 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.4333
# - Epoch [2] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.362064
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.466862
# -- iteration [299] finished, time cost: 0.13  and loss value: 2.138845
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.058025
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.422433
# -- iteration [599] finished, time cost: 0.14  and loss value: 1.430083
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.294573
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.405104
# - Epoch [2] train finished, time cost: 1.07
# Epoch [2] evaluation metrics Accuracy: 0.6364 Precision: 0.7500 Recall: 0.0789 ROC_AUC: 0.6475
# - Epoch [3] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.397507
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.482042
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.134672
# -- iteration [399] finished, time cost: 0.10  and loss value: 1.004289
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.413191
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.917187
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.275812
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.498830
# - Epoch [3] train finished, time cost: 1.03
# Epoch [3] evaluation metrics Accuracy: 0.6700 Precision: 0.6667 Recall: 0.2807 ROC_AUC: 0.6975
# - Epoch [4] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.486097
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.538684
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.007824
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.938922
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.398803
# -- iteration [599] finished, time cost: 0.10  and loss value: 0.688563
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.249928
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.523040
# - Epoch [4] train finished, time cost: 0.99
# Epoch [4] evaluation metrics Accuracy: 0.6846 Precision: 0.6871 Recall: 0.3275 ROC_AUC: 0.7070
# - Epoch [5] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.487168
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.545087
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.004781
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.957469
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.359390
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.761729
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.211125
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.460034
# - Epoch [5] train finished, time cost: 1.02
# Epoch [5] evaluation metrics Accuracy: 0.6734 Precision: 0.6917 Recall: 0.2690 ROC_AUC: 0.7068
# - Epoch [6] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.414692
# -- iteration [199] finished, time cost: 0.10  and loss value: 0.508416
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.014691
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.025481
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.316824
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.007472
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.181260
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.381919
# - Epoch [6] train finished, time cost: 1.02
# Epoch [6] evaluation metrics Accuracy: 0.6655 Precision: 0.7444 Recall: 0.1959 ROC_AUC: 0.7050
# - Epoch [7] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.346635
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.475348
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.061353
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.068473
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.294332
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.222980
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.175555
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.346096
# - Epoch [7] train finished, time cost: 1.00
# Epoch [7] evaluation metrics Accuracy: 0.6554 Precision: 0.7869 Recall: 0.1404 ROC_AUC: 0.7106
# - Epoch [8] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.329941
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.482914
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.121054
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.025949
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.301288
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.210715
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.197834
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.367303
# - Epoch [8] train finished, time cost: 1.04
# Epoch [8] evaluation metrics Accuracy: 0.6633 Precision: 0.8281 Recall: 0.1550 ROC_AUC: 0.7373
# - Epoch [9] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.370333
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.539771
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.097893
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.911756
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.329544
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.018229
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.239526
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.425356
# - Epoch [9] train finished, time cost: 1.02
# Epoch [9] evaluation metrics Accuracy: 0.6723 Precision: 0.8205 Recall: 0.1871 ROC_AUC: 0.7713
# - Epoch [10] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.439469
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.620314
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.063006
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.797638
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.357214
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.849996
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.277492
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.474571
# - Epoch [10] train finished, time cost: 1.06
# Epoch [10] evaluation metrics Accuracy: 0.6857 Precision: 0.8444 Recall: 0.2222 ROC_AUC: 0.7939
# - Epoch [11] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.486164
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.681105
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.062240
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.733375
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.365204
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.807292
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.291134
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.482471
# - Epoch [11] train finished, time cost: 0.97
# Epoch [11] evaluation metrics Accuracy: 0.6790 Precision: 0.8590 Recall: 0.1959 ROC_AUC: 0.8078
# - Epoch [12] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.485131
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.701268
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.096054
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.717813
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.354187
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.857305
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.284016
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.462854
# - Epoch [12] train finished, time cost: 1.02
# Epoch [12] evaluation metrics Accuracy: 0.6700 Precision: 0.8429 Recall: 0.1725 ROC_AUC: 0.8154
# - Epoch [13] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.461533
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.698898
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.141327
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.720003
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.338707
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.904347
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.273333
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.449334
# - Epoch [13] train finished, time cost: 1.02
# Epoch [13] evaluation metrics Accuracy: 0.6689 Precision: 0.8406 Recall: 0.1696 ROC_AUC: 0.8186
# - Epoch [14] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.449550
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.701935
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.135017
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.712922
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.328017
# -- iteration [599] finished, time cost: 0.10  and loss value: 0.886620
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.266807
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.453408
# - Epoch [14] train finished, time cost: 1.02
# Epoch [14] evaluation metrics Accuracy: 0.6768 Precision: 0.8553 Recall: 0.1901 ROC_AUC: 0.8198
# - Epoch [15] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.453198
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.715678
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.095253
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.697990
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.319144
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.841199
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.259598
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.460347
# - Epoch [15] train finished, time cost: 1.05
# Epoch [15] evaluation metrics Accuracy: 0.6835 Precision: 0.8659 Recall: 0.2076 ROC_AUC: 0.8206
# - Epoch [16] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.454015
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.725801
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.072135
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.691048
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.306432
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.825990
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.247140
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.455631
# - Epoch [16] train finished, time cost: 1.03
# Epoch [16] evaluation metrics Accuracy: 0.6869 Precision: 0.8706 Recall: 0.2164 ROC_AUC: 0.8218
# - Epoch [17] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.441185
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.723677
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.068678
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.696250
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.290498
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.846936
# -- iteration [699] finished, time cost: 0.16  and loss value: 0.232538
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.442469
# - Epoch [17] train finished, time cost: 1.05
# Epoch [17] evaluation metrics Accuracy: 0.6835 Precision: 0.8659 Recall: 0.2076 ROC_AUC: 0.8232
# - Epoch [18] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.422800
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.716651
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.072203
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.702818
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.276643
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.869611
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.222070
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.433802
# - Epoch [18] train finished, time cost: 1.03
# Epoch [18] evaluation metrics Accuracy: 0.6846 Precision: 0.8675 Recall: 0.2105 ROC_AUC: 0.8250
# - Epoch [19] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.412114
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.717457
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.070611
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.698598
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.268333
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.865480
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.218112
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.435912
# - Epoch [19] train finished, time cost: 1.04
# Epoch [19] evaluation metrics Accuracy: 0.6936 Precision: 0.8791 Recall: 0.2339 ROC_AUC: 0.8267
# - Epoch [20] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.412158
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.729694
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.063639
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.683434
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.264113
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.842487
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.217821
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.443769
# - Epoch [20] train finished, time cost: 1.03
# Epoch [20] evaluation metrics Accuracy: 0.6981 Precision: 0.8842 Recall: 0.2456 ROC_AUC: 0.8278
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-95cfa7b690a7> in <module>
#     118
#     119 trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
# --> 120 saver = ms.trainer.Saver('./epoches10')
#     121 saver.save(model_file_name='my_model.json',
#     122            weights_file_name='my_weights.npz', service_signature=sig)
#
# AttributeError: module 'HuichuanFlow.trainer' has no attribute 'Saver'
