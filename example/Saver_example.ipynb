# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import HuichuanFlow as ms
from HuichuanFlow.trainer import SimpleTrainer

# 读取数据，去掉无用列
data = pd.read_csv("../data/titanic.csv").drop(["PassengerId", 
                  "Name", "Ticket", "Cabin"], axis=1)

# 构造编码类
le = LabelEncoder()
ohe = OneHotEncoder(sparse=False)

# 对类别型特征做One-Hot编码
Pclass = ohe.fit_transform(le.fit_transform(data["Pclass"].fillna(0)).reshape(-1, 1))
Sex = ohe.fit_transform(le.fit_transform(data["Sex"].fillna("")).reshape(-1, 1))
Embarked = ohe.fit_transform(le.fit_transform(data["Embarked"].fillna("")).reshape(-1, 1))

# 组合特征列
features = np.concatenate([Pclass,
                           Sex,
                           data[["Age"]].fillna(0),
                           data[["SibSp"]].fillna(0),
                           data[["Parch"]].fillna(0),
                           data[["Fare"]].fillna(0),
                           Embarked
                           ], axis=1)

# 标签
labels = data["Survived"].values * 2 - 1

# 特征维数
dimension = features.shape[1]

# 嵌入向量维度
k = 2

# 一次项
x = ms.core.Variable(dim=(dimension, 1), init=False, trainable=False)

# 三个类别类特征的三套One-Hot
x_Pclass = ms.core.Variable(dim=(Pclass.shape[1], 1), init=False, trainable=False)
x_Sex = ms.core.Variable(dim=(Sex.shape[1], 1), init=False, trainable=False)
x_Embarked = ms.core.Variable(dim=(Embarked.shape[1], 1), init=False, trainable=False)


# 标签
label = ms.core.Variable(dim=(1, 1), init=False, trainable=False)

# 一次项权值向量
w = ms.core.Variable(dim=(1, dimension), init=True, trainable=True)

# 类别类特征的嵌入矩阵
E_Pclass = ms.core.Variable(dim=(k, Pclass.shape[1]), init=True, trainable=True)
E_Sex = ms.core.Variable(dim=(k, Sex.shape[1]), init=True, trainable=True)
E_Embarked = ms.core.Variable(dim=(k, Embarked.shape[1]), init=True, trainable=True)

# 偏置
b = ms.core.Variable(dim=(1, 1), init=True, trainable=True)


# Wide部分
wide = ms.ops.MatMul(w, x)


# Deep部分，三个嵌入向量
embedding_Pclass = ms.ops.MatMul(E_Pclass, x_Pclass)
embedding_Sex = ms.ops.MatMul(E_Sex, x_Sex)
embedding_Embarked = ms.ops.MatMul(E_Embarked, x_Embarked)

# 将三个嵌入向量连接在一起
embedding = ms.ops.Concat(
        embedding_Pclass,
        embedding_Sex,
        embedding_Embarked
        )

# 第一隐藏层
hidden_1 = ms.layer.fc(embedding, 3 * k, 8, "ReLU")

# 第二隐藏层
hidden_2 = ms.layer.fc(hidden_1, 8, 4, "ReLU")

# 输出层
deep = ms.layer.fc(hidden_2, 4, 1, None)

# 输出
output = ms.ops.Add(wide, deep, b)

# 预测概率
predict = ms.ops.Logistic(output)

# 损失函数
loss = ms.ops.loss.LogLoss(ms.ops.Multiply(label, output))

learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)
accuracy = ms.ops.metrics.Accuracy(output, label)
precision = ms.ops.metrics.Precision(output, label)
recall = ms.ops.metrics.Recall(output, label)
auc = ms.ops.metrics.ROC_AUC(output, label)
roc = ms.ops.metrics.ROC(output, label)

batch_size = 16

trainer = SimpleTrainer([x, x_Pclass, x_Sex, x_Embarked], label,
                        loss, optimizer, epoches=20, batch=16,eval_on_train=True,metrics_ops=[accuracy,precision,recall,auc])
train_inputs = {
    x.name: features,
    x_Pclass.name: features[:, :3],
    x_Sex.name: features[:, 3:5],
    x_Embarked.name: features[:, 9:]
}

trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
# Out:
# [INIT] Variable weights init finished
# - Epoch [1] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.669050
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.672893
# -- iteration [299] finished, time cost: 0.13  and loss value: 1.597073
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.836376
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.522626
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.308126
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.380116
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.398707
# - Epoch [1] train finished, time cost: 1.06
# Epoch [1] evaluation metrics Accuracy: 0.6162 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.4277
# - Epoch [2] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.339343
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.447724
# -- iteration [299] finished, time cost: 0.14  and loss value: 2.683094
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.104459
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.404126
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.625644
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.275634
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.362794
# - Epoch [2] train finished, time cost: 1.06
# Epoch [2] evaluation metrics Accuracy: 0.6229 Precision: 0.7500 Recall: 0.0263 ROC_AUC: 0.6017
# - Epoch [3] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.353080
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.452762
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.381743
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.049060
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.404507
# -- iteration [599] finished, time cost: 0.12  and loss value: 1.078329
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.275733
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.470495
# - Epoch [3] train finished, time cost: 1.05
# Epoch [3] evaluation metrics Accuracy: 0.6667 Precision: 0.6923 Recall: 0.2368 ROC_AUC: 0.6947
# - Epoch [4] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.468558
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.533664
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.015125
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.929008
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.413868
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.703273
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.273453
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.544530
# - Epoch [4] train finished, time cost: 1.10
# Epoch [4] evaluation metrics Accuracy: 0.6857 Precision: 0.6824 Recall: 0.3392 ROC_AUC: 0.7106
# - Epoch [5] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.521447
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.574210
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.004319
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.900223
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.388854
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.666258
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.242669
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.515005
# - Epoch [5] train finished, time cost: 1.07
# Epoch [5] evaluation metrics Accuracy: 0.6790 Precision: 0.6818 Recall: 0.3070 ROC_AUC: 0.7142
# - Epoch [6] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.472612
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.552304
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.007852
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.951312
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.343667
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.845651
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.204132
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.432057
# - Epoch [6] train finished, time cost: 1.04
# Epoch [6] evaluation metrics Accuracy: 0.6655 Precision: 0.6964 Recall: 0.2281 ROC_AUC: 0.7137
# - Epoch [7] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.389799
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.507652
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.031911
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.020322
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.306362
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.103027
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.181902
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.367389
# - Epoch [7] train finished, time cost: 1.06
# Epoch [7] evaluation metrics Accuracy: 0.6599 Precision: 0.7910 Recall: 0.1550 ROC_AUC: 0.7127
# - Epoch [8] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.339560
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.486126
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.097063
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.035500
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.294442
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.231263
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.186398
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.355007
# - Epoch [8] train finished, time cost: 1.08
# Epoch [8] evaluation metrics Accuracy: 0.6554 Precision: 0.8070 Recall: 0.1345 ROC_AUC: 0.7280
# - Epoch [9] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.345903
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.512198
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.124193
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.964550
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.309912
# -- iteration [599] finished, time cost: 0.12  and loss value: 1.133784
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.216564
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.393173
# - Epoch [9] train finished, time cost: 1.10
# Epoch [9] evaluation metrics Accuracy: 0.6678 Precision: 0.8382 Recall: 0.1667 ROC_AUC: 0.7600
# - Epoch [10] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.399661
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.579930
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.085158
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.849848
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.338486
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.941215
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.257698
# -- iteration [799] finished, time cost: 0.14  and loss value: 0.451226
# - Epoch [10] train finished, time cost: 1.14
# Epoch [10] evaluation metrics Accuracy: 0.6779 Precision: 0.8395 Recall: 0.1988 ROC_AUC: 0.7895
# - Epoch [11] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.462837
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.654289
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.060297
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.757825
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.357912
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.819647
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.285391
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.485949
# - Epoch [11] train finished, time cost: 1.10
# Epoch [11] evaluation metrics Accuracy: 0.6857 Precision: 0.8523 Recall: 0.2193 ROC_AUC: 0.8052
# - Epoch [12] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.491169
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.697857
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.066199
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.716976
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.356282
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.812574
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.287638
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.481184
# - Epoch [12] train finished, time cost: 1.10
# Epoch [12] evaluation metrics Accuracy: 0.6768 Precision: 0.8553 Recall: 0.1901 ROC_AUC: 0.8128
# - Epoch [13] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.14  and loss value: 0.477743
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.704348
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.098245
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.714820
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.340245
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.870508
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.274859
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.458740
# - Epoch [13] train finished, time cost: 1.11
# Epoch [13] evaluation metrics Accuracy: 0.6700 Precision: 0.8429 Recall: 0.1725 ROC_AUC: 0.8180
# - Epoch [14] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.452391
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.696971
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.128883
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.721166
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.323746
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.909819
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.262996
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.446691
# - Epoch [14] train finished, time cost: 1.11
# Epoch [14] evaluation metrics Accuracy: 0.6667 Precision: 0.8358 Recall: 0.1637 ROC_AUC: 0.8205
# - Epoch [15] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.441494
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.699040
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.117048
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.714863
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.313176
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.889956
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.256783
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.451207
# - Epoch [15] train finished, time cost: 1.09
# Epoch [15] evaluation metrics Accuracy: 0.6768 Precision: 0.8553 Recall: 0.1901 ROC_AUC: 0.8224
# - Epoch [16] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.444871
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.712490
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.084637
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.699627
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.304804
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.847354
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.250832
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.458874
# - Epoch [16] train finished, time cost: 1.10
# Epoch [16] evaluation metrics Accuracy: 0.6846 Precision: 0.8675 Recall: 0.2105 ROC_AUC: 0.8233
# - Epoch [17] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.446228
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.724266
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.065207
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.689860
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.293101
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.829973
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.240269
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.457237
# - Epoch [17] train finished, time cost: 1.09
# Epoch [17] evaluation metrics Accuracy: 0.6925 Precision: 0.8778 Recall: 0.2310 ROC_AUC: 0.8242
# - Epoch [18] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.435641
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.726484
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.060688
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.689748
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.277442
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.845502
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.226337
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.447752
# - Epoch [18] train finished, time cost: 1.09
# Epoch [18] evaluation metrics Accuracy: 0.6902 Precision: 0.8750 Recall: 0.2251 ROC_AUC: 0.8261
# - Epoch [19] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.417621
# -- iteration [199] finished, time cost: 0.14  and loss value: 0.724367
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.062289
# -- iteration [399] finished, time cost: 0.13  and loss value: 0.691285
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.260897
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.869226
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.213353
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.440526
# - Epoch [19] train finished, time cost: 1.16
# Epoch [19] evaluation metrics Accuracy: 0.6936 Precision: 0.8791 Recall: 0.2339 ROC_AUC: 0.8288
# - Epoch [20] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.402218
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.729220
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.060679
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.682546
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.245719
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.875725
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.203240
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.443623
# - Epoch [20] train finished, time cost: 1.11
# Epoch [20] evaluation metrics Accuracy: 0.6981 Precision: 0.8842 Recall: 0.2456 ROC_AUC: 0.8319

# %%
saver = ms.trainer.Saver('./epoches10')
saver.save(model_file_name='my_model.json',
           weights_file_name='my_weights.npz')
# Out:
# Save model into file: ./epoches10/my_model.json
# Save weights to file: ./epoches10/my_weights.npz
