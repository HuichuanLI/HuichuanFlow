# %%
import sys
sys.path.append('../')

import numpy as np
import HuichuanFlow as ms
from scipy import signal


# 构造正弦波和方波两类样本的函数 
# 构造正弦波和方波两类样本的函数
def get_sequence_data(dimension=10, length=10,
                      number_of_examples=1000, train_set_ratio=0.7, seed=42):
    """
    生成两类序列数据。
    """
    xx = []

    # 正弦波
    xx.append(np.sin(np.arange(0, 10, 10 / length)).reshape(-1, 1))

    # 方波
    xx.append(np.array(signal.square(np.arange(0, 10, 10 / length))).reshape(-1, 1))

    data = []
    for i in range(2):
        x = xx[i]
        for j in range(number_of_examples // 2):
            sequence = x + np.random.normal(0, 0.6, (len(x), dimension))  # 加入噪声
            label = np.array([int(i == k) for k in range(2)])
            data.append(np.c_[sequence.reshape(1, -1), label.reshape(1, -1)])

    # 把各个类别的样本合在一起
    data = np.concatenate(data, axis=0)

    # 随机打乱样本顺序
    np.random.shuffle(data)

    # 计算训练样本数量
    train_set_size = int(number_of_examples * train_set_ratio)  # 训练集样本数量

    # 将训练集和测试集、特征和标签分开
    return (data[:train_set_size, :-2].reshape(-1, length, dimension),
            data[:train_set_size, -2:],
            data[train_set_size:, :-2].reshape(-1, length, dimension),
            data[train_set_size:, -2:])


# 构造RNN
seq_len = 96  # 序列长度
dimension = 16  # 输入维度
status_dimension = 12  # 状态维度

signal_train, label_train, signal_test, label_test = get_sequence_data(length=seq_len, dimension=dimension)

# 输入向量节点
inputs = [ms.core.Variable(dim=(dimension, 1), init=False, trainable=False) for i in range(seq_len)]
 
# 输入权值矩阵
U = ms.core.Variable(dim=(status_dimension, dimension), init=True, trainable=True)

# 状态权值矩阵
W = ms.core.Variable(dim=(status_dimension, status_dimension), init=True, trainable=True)

# 偏置向量
b = ms.core.Variable(dim=(status_dimension, 1), init=True, trainable=True)

# 保存各个时刻内部状态变量的数组
hiddens = []

last_step = None
for iv in inputs:
    h = ms.ops.Add(ms.ops.MatMul(U, iv), b)

    if last_step is not None:
        h = ms.ops.Add(ms.ops.MatMul(W, last_step), h)

    h = ms.ops.ReLU(h)

    last_step = h
    hiddens.append(last_step)


# 焊接点，暂时不连接父节点
welding_point = ms.ops.Welding()


# 全连接网络
fc1 = ms.layer.fc(welding_point, status_dimension, 40, "ReLU")
fc2 = ms.layer.fc(fc1, 40, 10, "ReLU")
output = ms.layer.fc(fc2, 10, 2, "None")

# 概率
predict = ms.ops.Logistic(output)

# 训练标签
label = ms.core.Variable((2, 1), trainable=False)

# 交叉熵损失
loss = ms.ops.CrossEntropyWithSoftMax(output, label)


# 训练
learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)

batch_size = 16

for epoch in range(30):
    
    batch_count = 0   
    for i, s in enumerate(signal_train):
        
        # 取一个变长序列
        start = np.random.randint(len(s) // 3)
        end = np.random.randint(len(s) // 3 + 30, len(s))
        s = s[start: end]
        
        # 将变长的输入序列赋给RNN的各输入向量节点
        for j in range(len(s)):
            inputs[j].set_value(np.mat(s[j]).T)    
        
        # 将临时的最后一个时刻与全连接网络焊接
        welding_point.weld(hiddens[j])
        
        label.set_value(np.mat(label_train[i, :]).T)
        
        optimizer.one_step()
        
        batch_count += 1
        if batch_count >= batch_size:
            
            print("epoch: {:d}, iteration: {:d}, loss: {:.3f}".format(epoch + 1, i + 1, loss.value[0, 0]))

            
            optimizer.update()
            batch_count = 0
        

    pred = []
    for i, s in enumerate(signal_test):
        
        start = np.random.randint(len(s) // 3)
        end = np.random.randint(len(s) // 3 + 30, len(s))
        s = s[start: end]
        
        for j in range(len(s)):
            inputs[j].set_value(np.mat(s[j]).T)    
        
        welding_point.weld(hiddens[j])

        predict.forward()
        pred.append(predict.value.A.ravel())
            
    pred = np.array(pred).argmax(axis=1)
    true = label_test.argmax(axis=1)
    
    accuracy = (true == pred).astype(np.int).sum() / len(signal_test)
    print("epoch: {:d}, accuracy: {:.5f}".format(epoch + 1, accuracy))
# Out:
# epoch: 1, iteration: 16, loss: 0.694
# epoch: 1, iteration: 32, loss: 0.687
# epoch: 1, iteration: 48, loss: 0.704
# epoch: 1, iteration: 64, loss: 0.677
# epoch: 1, iteration: 80, loss: 0.715
# epoch: 1, iteration: 96, loss: 0.720
# epoch: 1, iteration: 112, loss: 0.723
# epoch: 1, iteration: 128, loss: 0.727
# epoch: 1, iteration: 144, loss: 0.657
# epoch: 1, iteration: 160, loss: 0.654
# epoch: 1, iteration: 176, loss: 0.737
# epoch: 1, iteration: 192, loss: 0.647
# epoch: 1, iteration: 208, loss: 0.643
# epoch: 1, iteration: 224, loss: 0.639
# epoch: 1, iteration: 240, loss: 0.752
# epoch: 1, iteration: 256, loss: 0.752
# epoch: 1, iteration: 272, loss: 0.751
# epoch: 1, iteration: 288, loss: 0.640
# epoch: 1, iteration: 304, loss: 0.749
# epoch: 1, iteration: 320, loss: 0.642
# epoch: 1, iteration: 336, loss: 0.747
# epoch: 1, iteration: 352, loss: 0.644
# epoch: 1, iteration: 368, loss: 0.742
# epoch: 1, iteration: 384, loss: 0.648
# epoch: 1, iteration: 400, loss: 0.649
# epoch: 1, iteration: 416, loss: 0.652
# epoch: 1, iteration: 432, loss: 0.653
# epoch: 1, iteration: 448, loss: 0.736
# epoch: 1, iteration: 464, loss: 0.736
# epoch: 1, iteration: 480, loss: 0.650
# epoch: 1, iteration: 496, loss: 0.740
# epoch: 1, iteration: 512, loss: 0.740
# epoch: 1, iteration: 528, loss: 0.739
# epoch: 1, iteration: 544, loss: 0.649
# epoch: 1, iteration: 560, loss: 0.738
# epoch: 1, iteration: 576, loss: 0.736
# epoch: 1, iteration: 592, loss: 0.734
# epoch: 1, iteration: 608, loss: 0.656
# epoch: 1, iteration: 624, loss: 0.658
# epoch: 1, iteration: 640, loss: 0.661
# epoch: 1, iteration: 656, loss: 0.662
# epoch: 1, iteration: 672, loss: 0.664
# epoch: 1, iteration: 688, loss: 0.664
# epoch: 1, accuracy: 0.47333
# epoch: 2, iteration: 16, loss: 0.723
# epoch: 2, iteration: 32, loss: 0.664
# epoch: 2, iteration: 48, loss: 0.724
# epoch: 2, iteration: 64, loss: 0.663
# epoch: 2, iteration: 80, loss: 0.726
# epoch: 2, iteration: 96, loss: 0.727
# epoch: 2, iteration: 112, loss: 0.727
# epoch: 2, iteration: 128, loss: 0.728
# epoch: 2, iteration: 144, loss: 0.659
# epoch: 2, iteration: 160, loss: 0.658
# epoch: 2, iteration: 176, loss: 0.730
# epoch: 2, iteration: 192, loss: 0.656
# epoch: 2, iteration: 208, loss: 0.655
# epoch: 2, iteration: 224, loss: 0.654
# epoch: 2, iteration: 240, loss: 0.735
# epoch: 2, iteration: 256, loss: 0.735
# epoch: 2, iteration: 272, loss: 0.734
# epoch: 2, iteration: 288, loss: 0.654
# epoch: 2, iteration: 304, loss: 0.733
# epoch: 2, iteration: 320, loss: 0.655
# epoch: 2, iteration: 336, loss: 0.732
# epoch: 2, iteration: 352, loss: 0.658
# epoch: 2, iteration: 368, loss: 0.728
# epoch: 2, iteration: 384, loss: 0.661
# epoch: 2, iteration: 400, loss: 0.662
# epoch: 2, iteration: 416, loss: 0.664
# epoch: 2, iteration: 432, loss: 0.665
# epoch: 2, iteration: 448, loss: 0.722
# epoch: 2, iteration: 464, loss: 0.722
# epoch: 2, iteration: 480, loss: 0.665
# epoch: 2, iteration: 496, loss: 0.723
# epoch: 2, iteration: 512, loss: 0.723
# epoch: 2, iteration: 528, loss: 0.722
# epoch: 2, iteration: 544, loss: 0.665
# epoch: 2, iteration: 560, loss: 0.722
# epoch: 2, iteration: 576, loss: 0.721
# epoch: 2, iteration: 592, loss: 0.720
# epoch: 2, iteration: 608, loss: 0.669
# epoch: 2, iteration: 624, loss: 0.671
# epoch: 2, iteration: 640, loss: 0.673
# epoch: 2, iteration: 656, loss: 0.674
# epoch: 2, iteration: 672, loss: 0.675
# epoch: 2, iteration: 688, loss: 0.675
# epoch: 2, accuracy: 0.47333
# epoch: 3, iteration: 16, loss: 0.711
# epoch: 3, iteration: 32, loss: 0.675
# epoch: 3, iteration: 48, loss: 0.712
# epoch: 3, iteration: 64, loss: 0.673
# epoch: 3, iteration: 80, loss: 0.715
# epoch: 3, iteration: 96, loss: 0.716
# epoch: 3, iteration: 112, loss: 0.716
# epoch: 3, iteration: 128, loss: 0.717
# epoch: 3, iteration: 144, loss: 0.669
# epoch: 3, iteration: 160, loss: 0.668
# epoch: 3, iteration: 176, loss: 0.720
# epoch: 3, iteration: 192, loss: 0.666
# epoch: 3, iteration: 208, loss: 0.664
# epoch: 3, iteration: 224, loss: 0.663
# epoch: 3, iteration: 240, loss: 0.725
# epoch: 3, iteration: 256, loss: 0.725
# epoch: 3, iteration: 272, loss: 0.725
# epoch: 3, iteration: 288, loss: 0.663
# epoch: 3, iteration: 304, loss: 0.724
# epoch: 3, iteration: 320, loss: 0.664
# epoch: 3, iteration: 336, loss: 0.723
# epoch: 3, iteration: 352, loss: 0.665
# epoch: 3, iteration: 368, loss: 0.720
# epoch: 3, iteration: 384, loss: 0.668
# epoch: 3, iteration: 400, loss: 0.669
# epoch: 3, iteration: 416, loss: 0.671
# epoch: 3, iteration: 432, loss: 0.672
# epoch: 3, iteration: 448, loss: 0.715
# epoch: 3, iteration: 464, loss: 0.715
# epoch: 3, iteration: 480, loss: 0.671
# epoch: 3, iteration: 496, loss: 0.716
# epoch: 3, iteration: 512, loss: 0.716
# epoch: 3, iteration: 528, loss: 0.716
# epoch: 3, iteration: 544, loss: 0.670
# epoch: 3, iteration: 560, loss: 0.716
# epoch: 3, iteration: 576, loss: 0.716
# epoch: 3, iteration: 592, loss: 0.715
# epoch: 3, iteration: 608, loss: 0.674
# epoch: 3, iteration: 624, loss: 0.676
# epoch: 3, iteration: 640, loss: 0.678
# epoch: 3, iteration: 656, loss: 0.679
# epoch: 3, iteration: 672, loss: 0.680
# epoch: 3, iteration: 688, loss: 0.680
# epoch: 3, accuracy: 0.47333
# epoch: 4, iteration: 16, loss: 0.707
# epoch: 4, iteration: 32, loss: 0.679
# epoch: 4, iteration: 48, loss: 0.708
# epoch: 4, iteration: 64, loss: 0.677
# epoch: 4, iteration: 80, loss: 0.711
# epoch: 4, iteration: 96, loss: 0.712
# epoch: 4, iteration: 112, loss: 0.712
# epoch: 4, iteration: 128, loss: 0.713
# epoch: 4, iteration: 144, loss: 0.673
# epoch: 4, iteration: 160, loss: 0.671
# epoch: 4, iteration: 176, loss: 0.716
# epoch: 4, iteration: 192, loss: 0.669
# epoch: 4, iteration: 208, loss: 0.668
# epoch: 4, iteration: 224, loss: 0.666
# epoch: 4, iteration: 240, loss: 0.722
# epoch: 4, iteration: 256, loss: 0.722
# epoch: 4, iteration: 272, loss: 0.722
# epoch: 4, iteration: 288, loss: 0.666
# epoch: 4, iteration: 304, loss: 0.721
# epoch: 4, iteration: 320, loss: 0.666
# epoch: 4, iteration: 336, loss: 0.720
# epoch: 4, iteration: 352, loss: 0.668
# epoch: 4, iteration: 368, loss: 0.717
# epoch: 4, iteration: 384, loss: 0.671
# epoch: 4, iteration: 400, loss: 0.672
# epoch: 4, iteration: 416, loss: 0.673
# epoch: 4, iteration: 432, loss: 0.674
# epoch: 4, iteration: 448, loss: 0.713
# epoch: 4, iteration: 464, loss: 0.713
# epoch: 4, iteration: 480, loss: 0.673
# epoch: 4, iteration: 496, loss: 0.714
# epoch: 4, iteration: 512, loss: 0.714
# epoch: 4, iteration: 528, loss: 0.714
# epoch: 4, iteration: 544, loss: 0.672
# epoch: 4, iteration: 560, loss: 0.714
# epoch: 4, iteration: 576, loss: 0.714
# epoch: 4, iteration: 592, loss: 0.713
# epoch: 4, iteration: 608, loss: 0.676
# epoch: 4, iteration: 624, loss: 0.677
# epoch: 4, iteration: 640, loss: 0.679
# epoch: 4, iteration: 656, loss: 0.680
# epoch: 4, iteration: 672, loss: 0.681
# epoch: 4, iteration: 688, loss: 0.681
# epoch: 4, accuracy: 0.47333
# epoch: 5, iteration: 16, loss: 0.706
# epoch: 5, iteration: 32, loss: 0.680
# epoch: 5, iteration: 48, loss: 0.707
# epoch: 5, iteration: 64, loss: 0.679
# epoch: 5, iteration: 80, loss: 0.709
# epoch: 5, iteration: 96, loss: 0.711
# epoch: 5, iteration: 112, loss: 0.711
# epoch: 5, iteration: 128, loss: 0.712
# epoch: 5, iteration: 144, loss: 0.674
# epoch: 5, iteration: 160, loss: 0.673
# epoch: 5, iteration: 176, loss: 0.715
# epoch: 5, iteration: 192, loss: 0.670
# epoch: 5, iteration: 208, loss: 0.669
# epoch: 5, iteration: 224, loss: 0.667
# epoch: 5, iteration: 240, loss: 0.721
# epoch: 5, iteration: 256, loss: 0.721
# epoch: 5, iteration: 272, loss: 0.720
# epoch: 5, iteration: 288, loss: 0.667
# epoch: 5, iteration: 304, loss: 0.720
# epoch: 5, iteration: 320, loss: 0.667
# epoch: 5, iteration: 336, loss: 0.719
# epoch: 5, iteration: 352, loss: 0.669
# epoch: 5, iteration: 368, loss: 0.717
# epoch: 5, iteration: 384, loss: 0.671
# epoch: 5, iteration: 400, loss: 0.672
# epoch: 5, iteration: 416, loss: 0.674
# epoch: 5, iteration: 432, loss: 0.675
# epoch: 5, iteration: 448, loss: 0.712
# epoch: 5, iteration: 464, loss: 0.712
# epoch: 5, iteration: 480, loss: 0.674
# epoch: 5, iteration: 496, loss: 0.713
# epoch: 5, iteration: 512, loss: 0.714
# epoch: 5, iteration: 528, loss: 0.714
# epoch: 5, iteration: 544, loss: 0.673
# epoch: 5, iteration: 560, loss: 0.714
# epoch: 5, iteration: 576, loss: 0.713
# epoch: 5, iteration: 592, loss: 0.712
# epoch: 5, iteration: 608, loss: 0.676
# epoch: 5, iteration: 624, loss: 0.678
# epoch: 5, iteration: 640, loss: 0.680
# epoch: 5, iteration: 656, loss: 0.680
# epoch: 5, iteration: 672, loss: 0.681
# epoch: 5, iteration: 688, loss: 0.681
# epoch: 5, accuracy: 0.47333
# epoch: 6, iteration: 16, loss: 0.705
# epoch: 6, iteration: 32, loss: 0.680
# epoch: 6, iteration: 48, loss: 0.707
# epoch: 6, iteration: 64, loss: 0.679
# epoch: 6, iteration: 80, loss: 0.709
# epoch: 6, iteration: 96, loss: 0.710
# epoch: 6, iteration: 112, loss: 0.711
# epoch: 6, iteration: 128, loss: 0.712
# epoch: 6, iteration: 144, loss: 0.674
# epoch: 6, iteration: 160, loss: 0.673
# epoch: 6, iteration: 176, loss: 0.715
# epoch: 6, iteration: 192, loss: 0.671
# epoch: 6, iteration: 208, loss: 0.669
# epoch: 6, iteration: 224, loss: 0.667
# epoch: 6, iteration: 240, loss: 0.720
# epoch: 6, iteration: 256, loss: 0.721
# epoch: 6, iteration: 272, loss: 0.720
# epoch: 6, iteration: 288, loss: 0.667
# epoch: 6, iteration: 304, loss: 0.720
# epoch: 6, iteration: 320, loss: 0.667
# epoch: 6, iteration: 336, loss: 0.719
# epoch: 6, iteration: 352, loss: 0.669
# epoch: 6, iteration: 368, loss: 0.716
# epoch: 6, iteration: 384, loss: 0.671
# epoch: 6, iteration: 400, loss: 0.672
# epoch: 6, iteration: 416, loss: 0.673
# epoch: 6, iteration: 432, loss: 0.669
# epoch: 6, iteration: 448, loss: 0.722
# epoch: 6, iteration: 464, loss: 0.713
# epoch: 6, iteration: 480, loss: 0.644
# epoch: 6, iteration: 496, loss: 0.717
# epoch: 6, iteration: 512, loss: 0.792
# epoch: 6, iteration: 528, loss: 0.812
# epoch: 6, iteration: 544, loss: 0.530
# epoch: 6, iteration: 560, loss: 0.716
# epoch: 6, iteration: 576, loss: 0.895
# epoch: 6, iteration: 592, loss: 0.920
# epoch: 6, iteration: 608, loss: 0.576
# epoch: 6, iteration: 624, loss: 0.683
# epoch: 6, iteration: 640, loss: 0.555
# epoch: 6, iteration: 656, loss: 0.577
# epoch: 6, iteration: 672, loss: 0.596
# epoch: 6, iteration: 688, loss: 0.578
# epoch: 6, accuracy: 0.47333
# epoch: 7, iteration: 16, loss: 0.788
# epoch: 7, iteration: 32, loss: 0.499
# epoch: 7, iteration: 48, loss: 0.926
# epoch: 7, iteration: 64, loss: 0.469
# epoch: 7, iteration: 80, loss: 0.748
# epoch: 7, iteration: 96, loss: 0.797
# epoch: 7, iteration: 112, loss: 1.087
# epoch: 7, iteration: 128, loss: 1.320
# epoch: 7, iteration: 144, loss: 0.325
# epoch: 7, iteration: 160, loss: 0.359
# epoch: 7, iteration: 176, loss: 0.682
# epoch: 7, iteration: 192, loss: 0.348
# epoch: 7, iteration: 208, loss: 0.424
# epoch: 7, iteration: 224, loss: 0.414
# epoch: 7, iteration: 240, loss: 0.647
# epoch: 7, iteration: 256, loss: 0.559
# epoch: 7, iteration: 272, loss: 0.723
# epoch: 7, iteration: 288, loss: 0.445
# epoch: 7, iteration: 304, loss: 1.014
# epoch: 7, iteration: 320, loss: 0.492
# epoch: 7, iteration: 336, loss: 0.363
# epoch: 7, iteration: 352, loss: 0.566
# epoch: 7, iteration: 368, loss: 0.606
# epoch: 7, iteration: 384, loss: 0.899
# epoch: 7, iteration: 400, loss: 0.469
# epoch: 7, iteration: 416, loss: 0.911
# epoch: 7, iteration: 432, loss: 0.437
# epoch: 7, iteration: 448, loss: 0.106
# epoch: 7, iteration: 464, loss: 0.846
# epoch: 7, iteration: 480, loss: 0.288
# epoch: 7, iteration: 496, loss: 0.133
# epoch: 7, iteration: 512, loss: 0.072
# epoch: 7, iteration: 528, loss: 0.035
# epoch: 7, iteration: 544, loss: 0.171
# epoch: 7, iteration: 560, loss: 0.989
# epoch: 7, iteration: 576, loss: 0.104
# epoch: 7, iteration: 592, loss: 0.391
# epoch: 7, iteration: 608, loss: 0.923
# epoch: 7, iteration: 624, loss: 2.044
# epoch: 7, iteration: 640, loss: 1.273
# epoch: 7, iteration: 656, loss: 0.311
# epoch: 7, iteration: 672, loss: 0.159
# epoch: 7, iteration: 688, loss: 0.317
# epoch: 7, accuracy: 0.70333
# epoch: 8, iteration: 16, loss: 1.436
# epoch: 8, iteration: 32, loss: 0.167
# epoch: 8, iteration: 48, loss: 0.473
# epoch: 8, iteration: 64, loss: 0.188
# epoch: 8, iteration: 80, loss: 1.527
# epoch: 8, iteration: 96, loss: 0.654
# epoch: 8, iteration: 112, loss: 1.284
# epoch: 8, iteration: 128, loss: 0.290
# epoch: 8, iteration: 144, loss: 0.777
# epoch: 8, iteration: 160, loss: 0.385
# epoch: 8, iteration: 176, loss: 0.812
# epoch: 8, iteration: 192, loss: 1.236
# epoch: 8, iteration: 208, loss: 0.288
# epoch: 8, iteration: 224, loss: 0.175
# epoch: 8, iteration: 240, loss: 0.678
# epoch: 8, iteration: 256, loss: 0.022
# epoch: 8, iteration: 272, loss: 0.743
# epoch: 8, iteration: 288, loss: 0.484
# epoch: 8, iteration: 304, loss: 0.229
# epoch: 8, iteration: 320, loss: 0.402
# epoch: 8, iteration: 336, loss: 0.086
# epoch: 8, iteration: 352, loss: 0.400
# epoch: 8, iteration: 368, loss: 0.214
# epoch: 8, iteration: 384, loss: 0.451
# epoch: 8, iteration: 400, loss: 0.444
# epoch: 8, iteration: 416, loss: 0.585
# epoch: 8, iteration: 432, loss: 0.504
# epoch: 8, iteration: 448, loss: 0.044
# epoch: 8, iteration: 464, loss: 0.008
# epoch: 8, iteration: 480, loss: 0.233
# epoch: 8, iteration: 496, loss: 1.384
# epoch: 8, iteration: 512, loss: 0.008
# epoch: 8, iteration: 528, loss: 1.710
# epoch: 8, iteration: 544, loss: 0.171
# epoch: 8, iteration: 560, loss: 1.668
# epoch: 8, iteration: 576, loss: 1.319
# epoch: 8, iteration: 592, loss: 1.708
# epoch: 8, iteration: 608, loss: 0.493
# epoch: 8, iteration: 624, loss: 0.345
# epoch: 8, iteration: 640, loss: 0.153
# epoch: 8, iteration: 656, loss: 0.455
# epoch: 8, iteration: 672, loss: 0.741
# epoch: 8, iteration: 688, loss: 0.719
# epoch: 8, accuracy: 0.81000
# epoch: 9, iteration: 16, loss: 0.165
# epoch: 9, iteration: 32, loss: 0.698
# epoch: 9, iteration: 48, loss: 0.837
# epoch: 9, iteration: 64, loss: 0.508
# epoch: 9, iteration: 80, loss: 0.903
# epoch: 9, iteration: 96, loss: 0.137
# epoch: 9, iteration: 112, loss: 1.098
# epoch: 9, iteration: 128, loss: 1.054
# epoch: 9, iteration: 144, loss: 0.429
# epoch: 9, iteration: 160, loss: 0.324
# epoch: 9, iteration: 176, loss: 0.004
# epoch: 9, iteration: 192, loss: 0.271
# epoch: 9, iteration: 208, loss: 0.345
# epoch: 9, iteration: 224, loss: 0.249
# epoch: 9, iteration: 240, loss: 0.703
# epoch: 9, iteration: 256, loss: 0.008
# epoch: 9, iteration: 272, loss: 1.130
# epoch: 9, iteration: 288, loss: 0.084
# epoch: 9, iteration: 304, loss: 0.039
# epoch: 9, iteration: 320, loss: 0.396
# epoch: 9, iteration: 336, loss: 0.005
# epoch: 9, iteration: 352, loss: 0.328
# epoch: 9, iteration: 368, loss: 0.001
# epoch: 9, iteration: 384, loss: 0.308
# epoch: 9, iteration: 400, loss: 0.526
# epoch: 9, iteration: 416, loss: 0.483
# epoch: 9, iteration: 432, loss: 0.503
# epoch: 9, iteration: 448, loss: 0.000
# epoch: 9, iteration: 464, loss: 0.002
# epoch: 9, iteration: 480, loss: 0.467
# epoch: 9, iteration: 496, loss: 0.000
# epoch: 9, iteration: 512, loss: 0.000
# epoch: 9, iteration: 528, loss: 0.000
# epoch: 9, iteration: 544, loss: 0.229
# epoch: 9, iteration: 560, loss: 1.084
# epoch: 9, iteration: 576, loss: 0.007
# epoch: 9, iteration: 592, loss: 1.465
# epoch: 9, iteration: 608, loss: 1.259
# epoch: 9, iteration: 624, loss: 0.356
# epoch: 9, iteration: 640, loss: 0.503
# epoch: 9, iteration: 656, loss: 0.261
# epoch: 9, iteration: 672, loss: 0.119
# epoch: 9, iteration: 688, loss: 0.404
# epoch: 9, accuracy: 0.78333
# epoch: 10, iteration: 16, loss: 0.000
# epoch: 10, iteration: 32, loss: 0.310
# epoch: 10, iteration: 48, loss: 1.188
# epoch: 10, iteration: 64, loss: 0.419
# epoch: 10, iteration: 80, loss: 0.000
# epoch: 10, iteration: 96, loss: 0.000
# epoch: 10, iteration: 112, loss: 0.525
# epoch: 10, iteration: 128, loss: 1.879
# epoch: 10, iteration: 144, loss: 0.216
# epoch: 10, iteration: 160, loss: 0.007
# epoch: 10, iteration: 176, loss: 0.997
# epoch: 10, iteration: 192, loss: 0.353
# epoch: 10, iteration: 208, loss: 0.387
# epoch: 10, iteration: 224, loss: 0.216
# epoch: 10, iteration: 240, loss: 0.000
# epoch: 10, iteration: 256, loss: 0.869
# epoch: 10, iteration: 272, loss: 0.979
# epoch: 10, iteration: 288, loss: 1.771
# epoch: 10, iteration: 304, loss: 0.001
# epoch: 10, iteration: 320, loss: 0.398
# epoch: 10, iteration: 336, loss: 0.000
# epoch: 10, iteration: 352, loss: 0.214
# epoch: 10, iteration: 368, loss: 0.001
# epoch: 10, iteration: 384, loss: 0.205
# epoch: 10, iteration: 400, loss: 0.045
# epoch: 10, iteration: 416, loss: 0.273
# epoch: 10, iteration: 432, loss: 0.469
# epoch: 10, iteration: 448, loss: 1.299
# epoch: 10, iteration: 464, loss: 0.000
# epoch: 10, iteration: 480, loss: 0.232
# epoch: 10, iteration: 496, loss: 0.073
# epoch: 10, iteration: 512, loss: 0.068
# epoch: 10, iteration: 528, loss: 0.000
# epoch: 10, iteration: 544, loss: 0.280
# epoch: 10, iteration: 560, loss: 0.012
# epoch: 10, iteration: 576, loss: 1.083
# epoch: 10, iteration: 592, loss: 0.011
# epoch: 10, iteration: 608, loss: 0.181
# epoch: 10, iteration: 624, loss: 0.432
# epoch: 10, iteration: 640, loss: 0.691
# epoch: 10, iteration: 656, loss: 0.141
# epoch: 10, iteration: 672, loss: 0.047
# epoch: 10, iteration: 688, loss: 0.312
# epoch: 10, accuracy: 0.83333
# epoch: 11, iteration: 16, loss: 0.001
# epoch: 11, iteration: 32, loss: 0.012
# epoch: 11, iteration: 48, loss: 0.881
# epoch: 11, iteration: 64, loss: 0.519
# epoch: 11, iteration: 80, loss: 0.000
# epoch: 11, iteration: 96, loss: 0.000
# epoch: 11, iteration: 112, loss: 0.009
# epoch: 11, iteration: 128, loss: 0.316
# epoch: 11, iteration: 144, loss: 0.143
# epoch: 11, iteration: 160, loss: 0.113
# epoch: 11, iteration: 176, loss: 2.233
# epoch: 11, iteration: 192, loss: 0.102
# epoch: 11, iteration: 208, loss: 0.075
# epoch: 11, iteration: 224, loss: 0.180
# epoch: 11, iteration: 240, loss: 0.000
# epoch: 11, iteration: 256, loss: 0.003
# epoch: 11, iteration: 272, loss: 0.005
# epoch: 11, iteration: 288, loss: 0.001
# epoch: 11, iteration: 304, loss: 1.297
# epoch: 11, iteration: 320, loss: 0.057
# epoch: 11, iteration: 336, loss: 0.000
# epoch: 11, iteration: 352, loss: 0.011
# epoch: 11, iteration: 368, loss: 1.138
# epoch: 11, iteration: 384, loss: 0.002
# epoch: 11, iteration: 400, loss: 0.082
# epoch: 11, iteration: 416, loss: 0.065
# epoch: 11, iteration: 432, loss: 0.114
# epoch: 11, iteration: 448, loss: 2.004
# epoch: 11, iteration: 464, loss: 1.770
# epoch: 11, iteration: 480, loss: 0.190
# epoch: 11, iteration: 496, loss: 0.867
# epoch: 11, iteration: 512, loss: 0.001
# epoch: 11, iteration: 528, loss: 0.002
# epoch: 11, iteration: 544, loss: 0.402
# epoch: 11, iteration: 560, loss: 0.133
# epoch: 11, iteration: 576, loss: 0.021
# epoch: 11, iteration: 592, loss: 0.796
# epoch: 11, iteration: 608, loss: 0.638
# epoch: 11, iteration: 624, loss: 0.660
# epoch: 11, iteration: 640, loss: 0.545
# epoch: 11, iteration: 656, loss: 0.556
# epoch: 11, iteration: 672, loss: 0.692
# epoch: 11, iteration: 688, loss: 0.621
# epoch: 11, accuracy: 0.79333
# epoch: 12, iteration: 16, loss: 0.000
# epoch: 12, iteration: 32, loss: 0.517
# epoch: 12, iteration: 48, loss: 0.000
# epoch: 12, iteration: 64, loss: 0.496
# epoch: 12, iteration: 80, loss: 0.086
# epoch: 12, iteration: 96, loss: 0.004
# epoch: 12, iteration: 112, loss: 0.636
# epoch: 12, iteration: 128, loss: 0.000
# epoch: 12, iteration: 144, loss: 0.446
# epoch: 12, iteration: 160, loss: 0.320
# epoch: 12, iteration: 176, loss: 0.756
# epoch: 12, iteration: 192, loss: 0.269
# epoch: 12, iteration: 208, loss: 0.067
# epoch: 12, iteration: 224, loss: 0.235
# epoch: 12, iteration: 240, loss: 0.977
# epoch: 12, iteration: 256, loss: 0.709
# epoch: 12, iteration: 272, loss: 0.000
# epoch: 12, iteration: 288, loss: 0.290
# epoch: 12, iteration: 304, loss: 0.000
# epoch: 12, iteration: 320, loss: 0.187
# epoch: 12, iteration: 336, loss: 0.129
# epoch: 12, iteration: 352, loss: 1.091
# epoch: 12, iteration: 368, loss: 0.000
# epoch: 12, iteration: 384, loss: 0.430
# epoch: 12, iteration: 400, loss: 0.256
# epoch: 12, iteration: 416, loss: 0.248
# epoch: 12, iteration: 432, loss: 0.347
# epoch: 12, iteration: 448, loss: 0.002
# epoch: 12, iteration: 464, loss: 0.065
# epoch: 12, iteration: 480, loss: 0.133
# epoch: 12, iteration: 496, loss: 0.000
# epoch: 12, iteration: 512, loss: 0.001
# epoch: 12, iteration: 528, loss: 0.000
# epoch: 12, iteration: 544, loss: 0.196
# epoch: 12, iteration: 560, loss: 0.000
# epoch: 12, iteration: 576, loss: 0.000
# epoch: 12, iteration: 592, loss: 1.155
# epoch: 12, iteration: 608, loss: 0.344
# epoch: 12, iteration: 624, loss: 0.342
# epoch: 12, iteration: 640, loss: 0.309
# epoch: 12, iteration: 656, loss: 0.271
# epoch: 12, iteration: 672, loss: 0.108
# epoch: 12, iteration: 688, loss: 0.239
# epoch: 12, accuracy: 0.79333
# epoch: 13, iteration: 16, loss: 0.908
# epoch: 13, iteration: 32, loss: 0.125
# epoch: 13, iteration: 48, loss: 0.002
# epoch: 13, iteration: 64, loss: 0.218
# epoch: 13, iteration: 80, loss: 0.000
# epoch: 13, iteration: 96, loss: 1.455
# epoch: 13, iteration: 112, loss: 1.897
# epoch: 13, iteration: 128, loss: 1.365
# epoch: 13, iteration: 144, loss: 0.002
# epoch: 13, iteration: 160, loss: 0.187
# epoch: 13, iteration: 176, loss: 1.245
# epoch: 13, iteration: 192, loss: 0.385
# epoch: 13, iteration: 208, loss: 0.227
# epoch: 13, iteration: 224, loss: 0.316
# epoch: 13, iteration: 240, loss: 0.175
# epoch: 13, iteration: 256, loss: 0.005
# epoch: 13, iteration: 272, loss: 0.000
# epoch: 13, iteration: 288, loss: 0.601
# epoch: 13, iteration: 304, loss: 0.014
# epoch: 13, iteration: 320, loss: 0.008
# epoch: 13, iteration: 336, loss: 1.209
# epoch: 13, iteration: 352, loss: 0.188
# epoch: 13, iteration: 368, loss: 0.000
# epoch: 13, iteration: 384, loss: 0.030
# epoch: 13, iteration: 400, loss: 0.123
# epoch: 13, iteration: 416, loss: 0.005
# epoch: 13, iteration: 432, loss: 0.177
# epoch: 13, iteration: 448, loss: 0.000
# epoch: 13, iteration: 464, loss: 1.819
# epoch: 13, iteration: 480, loss: 0.027
# epoch: 13, iteration: 496, loss: 0.000
# epoch: 13, iteration: 512, loss: 0.206
# epoch: 13, iteration: 528, loss: 1.330
# epoch: 13, iteration: 544, loss: 0.237
# epoch: 13, iteration: 560, loss: 0.229
# epoch: 13, iteration: 576, loss: 0.000
# epoch: 13, iteration: 592, loss: 0.940
# epoch: 13, iteration: 608, loss: 0.609
# epoch: 13, iteration: 624, loss: 0.502
# epoch: 13, iteration: 640, loss: 0.450
# epoch: 13, iteration: 656, loss: 0.413
# epoch: 13, iteration: 672, loss: 0.308
# epoch: 13, iteration: 688, loss: 0.409
# epoch: 13, accuracy: 0.84667
# epoch: 14, iteration: 16, loss: 0.000
# epoch: 14, iteration: 32, loss: 0.289
# epoch: 14, iteration: 48, loss: 0.005
# epoch: 14, iteration: 64, loss: 0.192
# epoch: 14, iteration: 80, loss: 0.000
# epoch: 14, iteration: 96, loss: 2.093
# epoch: 14, iteration: 112, loss: 0.000
# epoch: 14, iteration: 128, loss: 0.739
# epoch: 14, iteration: 144, loss: 0.188
# epoch: 14, iteration: 160, loss: 0.002
# epoch: 14, iteration: 176, loss: 1.066
# epoch: 14, iteration: 192, loss: 0.174
# epoch: 14, iteration: 208, loss: 0.209
# epoch: 14, iteration: 224, loss: 0.154
# epoch: 14, iteration: 240, loss: 1.068
# epoch: 14, iteration: 256, loss: 0.000
# epoch: 14, iteration: 272, loss: 0.943
# epoch: 14, iteration: 288, loss: 0.348
# epoch: 14, iteration: 304, loss: 1.200
# epoch: 14, iteration: 320, loss: 0.501
# epoch: 14, iteration: 336, loss: 0.000
# epoch: 14, iteration: 352, loss: 0.526
# epoch: 14, iteration: 368, loss: 0.000
# epoch: 14, iteration: 384, loss: 0.300
# epoch: 14, iteration: 400, loss: 0.586
# epoch: 14, iteration: 416, loss: 0.074
# epoch: 14, iteration: 432, loss: 0.487
# epoch: 14, iteration: 448, loss: 0.859
# epoch: 14, iteration: 464, loss: 0.038
# epoch: 14, iteration: 480, loss: 0.497
# epoch: 14, iteration: 496, loss: 0.000
# epoch: 14, iteration: 512, loss: 0.626
# epoch: 14, iteration: 528, loss: 0.000
# epoch: 14, iteration: 544, loss: 0.174
