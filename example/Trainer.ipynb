# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import HuichuanFlow as ms
from HuichuanFlow.trainer import SimpleTrainer

# 读取数据，去掉无用列
data = pd.read_csv("../data/titanic.csv").drop(["PassengerId", 
                  "Name", "Ticket", "Cabin"], axis=1)

# 构造编码类
le = LabelEncoder()
ohe = OneHotEncoder(sparse=False)

# 对类别型特征做One-Hot编码
Pclass = ohe.fit_transform(le.fit_transform(data["Pclass"].fillna(0)).reshape(-1, 1))
Sex = ohe.fit_transform(le.fit_transform(data["Sex"].fillna("")).reshape(-1, 1))
Embarked = ohe.fit_transform(le.fit_transform(data["Embarked"].fillna("")).reshape(-1, 1))

# 组合特征列
features = np.concatenate([Pclass,
                           Sex,
                           data[["Age"]].fillna(0),
                           data[["SibSp"]].fillna(0),
                           data[["Parch"]].fillna(0),
                           data[["Fare"]].fillna(0),
                           Embarked
                           ], axis=1)

# 标签
labels = data["Survived"].values * 2 - 1

# 特征维数
dimension = features.shape[1]

# 嵌入向量维度
k = 2

# 一次项
x = ms.core.Variable(dim=(dimension, 1), init=False, trainable=False)

# 三个类别类特征的三套One-Hot
x_Pclass = ms.core.Variable(dim=(Pclass.shape[1], 1), init=False, trainable=False)
x_Sex = ms.core.Variable(dim=(Sex.shape[1], 1), init=False, trainable=False)
x_Embarked = ms.core.Variable(dim=(Embarked.shape[1], 1), init=False, trainable=False)


# 标签
label = ms.core.Variable(dim=(1, 1), init=False, trainable=False)

# 一次项权值向量
w = ms.core.Variable(dim=(1, dimension), init=True, trainable=True)

# 类别类特征的嵌入矩阵
E_Pclass = ms.core.Variable(dim=(k, Pclass.shape[1]), init=True, trainable=True)
E_Sex = ms.core.Variable(dim=(k, Sex.shape[1]), init=True, trainable=True)
E_Embarked = ms.core.Variable(dim=(k, Embarked.shape[1]), init=True, trainable=True)

# 偏置
b = ms.core.Variable(dim=(1, 1), init=True, trainable=True)


# Wide部分
wide = ms.ops.MatMul(w, x)


# Deep部分，三个嵌入向量
embedding_Pclass = ms.ops.MatMul(E_Pclass, x_Pclass)
embedding_Sex = ms.ops.MatMul(E_Sex, x_Sex)
embedding_Embarked = ms.ops.MatMul(E_Embarked, x_Embarked)

# 将三个嵌入向量连接在一起
embedding = ms.ops.Concat(
        embedding_Pclass,
        embedding_Sex,
        embedding_Embarked
        )

# 第一隐藏层
hidden_1 = ms.layer.fc(embedding, 3 * k, 8, "ReLU")

# 第二隐藏层
hidden_2 = ms.layer.fc(hidden_1, 8, 4, "ReLU")

# 输出层
deep = ms.layer.fc(hidden_2, 4, 1, None)

# 输出
output = ms.ops.Add(wide, deep, b)

# 预测概率
predict = ms.ops.Logistic(output)

# 损失函数
loss = ms.ops.loss.LogLoss(ms.ops.Multiply(label, output))

learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)
accuracy = ms.ops.metrics.Accuracy(output, label)
precision = ms.ops.metrics.Precision(output, label)
recall = ms.ops.metrics.Recall(output, label)
auc = ms.ops.metrics.ROC_AUC(output, label)
roc = ms.ops.metrics.ROC(output, label)

batch_size = 16

trainer = SimpleTrainer([x, x_Pclass, x_Sex, x_Embarked], label,
                        loss, optimizer, epoches=20, batch=16,eval_on_train=True,metrics_ops=[accuracy,precision,recall,auc])
train_inputs = {
    x.name: features,
    x_Pclass.name: features[:, :3],
    x_Sex.name: features[:, 3:5],
    x_Embarked.name: features[:, 9:]
}

trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
# Out:
# [INIT] Variable weights init finished
# - Epoch [1] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.14  and loss value: 0.687042
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.689401
# -- iteration [299] finished, time cost: 0.12  and loss value: 1.817527
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.812061
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.540417
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.274872
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.408134
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.414122
# - Epoch [1] train finished, time cost: 1.05
# Epoch [1] evaluation metrics Accuracy: 0.6162 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.4241
# - Epoch [2] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.358658
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.464388
# -- iteration [299] finished, time cost: 0.12  and loss value: 2.494631
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.067435
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.420025
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.513272
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.293760
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.386303
# - Epoch [2] train finished, time cost: 1.02
# Epoch [2] evaluation metrics Accuracy: 0.6263 Precision: 0.7143 Recall: 0.0439 ROC_AUC: 0.6230
# - Epoch [3] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.376663
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.468401
# -- iteration [299] finished, time cost: 0.14  and loss value: 0.247487
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.024225
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.411619
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.992584
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.279346
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.485321
# - Epoch [3] train finished, time cost: 1.01
# Epoch [3] evaluation metrics Accuracy: 0.6678 Precision: 0.6769 Recall: 0.2573 ROC_AUC: 0.6966
# - Epoch [4] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.476162
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.533579
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.010836
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.937909
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.406546
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.691939
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.261709
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.533992
# - Epoch [4] train finished, time cost: 1.05
# Epoch [4] evaluation metrics Accuracy: 0.6857 Precision: 0.6845 Recall: 0.3363 ROC_AUC: 0.7083
# - Epoch [5] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.501611
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.554624
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.004187
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.936147
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.372577
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.706118
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.224942
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.487045
# - Epoch [5] train finished, time cost: 1.03
# Epoch [5] evaluation metrics Accuracy: 0.6723 Precision: 0.6689 Recall: 0.2895 ROC_AUC: 0.7102
# - Epoch [6] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.439929
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.523785
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.009464
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.998672
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.327595
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.916422
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.189896
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.405301
# - Epoch [6] train finished, time cost: 1.04
# Epoch [6] evaluation metrics Accuracy: 0.6689 Precision: 0.7327 Recall: 0.2164 ROC_AUC: 0.7089
# - Epoch [7] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.363270
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.483278
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.039457
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.059740
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.296381
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.162590
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.174849
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.352787
# - Epoch [7] train finished, time cost: 1.03
# Epoch [7] evaluation metrics Accuracy: 0.6599 Precision: 0.8000 Recall: 0.1520 ROC_AUC: 0.7105
# - Epoch [8] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.327332
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.473505
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.102312
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.051793
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.292289
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.236667
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.186520
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.354320
# - Epoch [8] train finished, time cost: 1.01
# Epoch [8] evaluation metrics Accuracy: 0.6599 Precision: 0.8197 Recall: 0.1462 ROC_AUC: 0.7306
# - Epoch [9] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.347474
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.511955
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.108177
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.960403
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.313319
# -- iteration [599] finished, time cost: 0.10  and loss value: 1.095733
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.221302
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.401401
# - Epoch [9] train finished, time cost: 1.04
# Epoch [9] evaluation metrics Accuracy: 0.6723 Precision: 0.8472 Recall: 0.1784 ROC_AUC: 0.7622
# - Epoch [10] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.408187
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.585609
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.070311
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.841604
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.342498
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.905842
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.262011
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.458080
# - Epoch [10] train finished, time cost: 1.04
# Epoch [10] evaluation metrics Accuracy: 0.6824 Precision: 0.8471 Recall: 0.2105 ROC_AUC: 0.7904
# - Epoch [11] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.466936
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.656308
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.055720
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.757179
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.358571
# -- iteration [599] finished, time cost: 0.13  and loss value: 0.811932
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.285552
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.483906
# - Epoch [11] train finished, time cost: 1.04
# Epoch [11] evaluation metrics Accuracy: 0.6835 Precision: 0.8571 Recall: 0.2105 ROC_AUC: 0.8053
# - Epoch [12] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.485158
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.692071
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.071206
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.724405
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.354052
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.827931
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.285345
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.473334
# - Epoch [12] train finished, time cost: 1.05
# Epoch [12] evaluation metrics Accuracy: 0.6734 Precision: 0.8493 Recall: 0.1813 ROC_AUC: 0.8138
# - Epoch [13] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.467747
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.695648
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.110793
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.723137
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.338855
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.886043
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.274553
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.454053
# - Epoch [13] train finished, time cost: 1.05
# Epoch [13] evaluation metrics Accuracy: 0.6667 Precision: 0.8358 Recall: 0.1637 ROC_AUC: 0.8190
# - Epoch [14] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.447791
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.693142
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.133538
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.722810
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.325657
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.904009
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.266307
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.449471
# - Epoch [14] train finished, time cost: 1.07
# Epoch [14] evaluation metrics Accuracy: 0.6700 Precision: 0.8429 Recall: 0.1725 ROC_AUC: 0.8213
# - Epoch [15] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.444466
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.701972
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.109330
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.710206
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.317245
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.868397
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.261353
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.457463
# - Epoch [15] train finished, time cost: 1.05
# Epoch [15] evaluation metrics Accuracy: 0.6813 Precision: 0.8625 Recall: 0.2018 ROC_AUC: 0.8224
# - Epoch [16] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.449698
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.716806
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.078389
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.695689
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.308432
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.831375
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.253742
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.461904
# - Epoch [16] train finished, time cost: 1.05
# Epoch [16] evaluation metrics Accuracy: 0.6869 Precision: 0.8706 Recall: 0.2164 ROC_AUC: 0.8229
# - Epoch [17] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.447043
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.724218
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.065267
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.691409
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.295757
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.829119
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.241576
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.455089
# - Epoch [17] train finished, time cost: 1.05
# Epoch [17] evaluation metrics Accuracy: 0.6891 Precision: 0.8736 Recall: 0.2222 ROC_AUC: 0.8240
# - Epoch [18] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.433108
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.721617
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.065433
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.695788
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.281614
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.851613
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.229141
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.444083
# - Epoch [18] train finished, time cost: 1.04
# Epoch [18] evaluation metrics Accuracy: 0.6846 Precision: 0.8675 Recall: 0.2105 ROC_AUC: 0.8254
# - Epoch [19] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.417952
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.718320
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.068249
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.697726
# -- iteration [499] finished, time cost: 0.13  and loss value: 0.270503
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.867050
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.221242
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.439374
# - Epoch [19] train finished, time cost: 1.06
# Epoch [19] evaluation metrics Accuracy: 0.6902 Precision: 0.8750 Recall: 0.2251 ROC_AUC: 0.8270
# - Epoch [20] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.411038
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.723666
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.065932
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.689344
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.264155
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.858821
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.218592
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.443615
# - Epoch [20] train finished, time cost: 1.07
# Epoch [20] evaluation metrics Accuracy: 0.6947 Precision: 0.8804 Recall: 0.2368 ROC_AUC: 0.8280

# %%
saver = ms.trainer.Saver('./epoches10')
saver.save(model_file_name='my_model.json',
           weights_file_name='my_weights.npz')
# Out:
# Save model into file: ./epoches10/my_model.json
# Save weights to file: ./epoches10/my_weights.npz
