# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import HuichuanFlow as ms
from HuichuanFlow.trainer import SimpleTrainer

# 读取数据，去掉无用列
data = pd.read_csv("../data/titanic.csv").drop(["PassengerId", 
                  "Name", "Ticket", "Cabin"], axis=1)

# 构造编码类
le = LabelEncoder()
ohe = OneHotEncoder(sparse=False)

# 对类别型特征做One-Hot编码
Pclass = ohe.fit_transform(le.fit_transform(data["Pclass"].fillna(0)).reshape(-1, 1))
Sex = ohe.fit_transform(le.fit_transform(data["Sex"].fillna("")).reshape(-1, 1))
Embarked = ohe.fit_transform(le.fit_transform(data["Embarked"].fillna("")).reshape(-1, 1))

# 组合特征列
features = np.concatenate([Pclass,
                           Sex,
                           data[["Age"]].fillna(0),
                           data[["SibSp"]].fillna(0),
                           data[["Parch"]].fillna(0),
                           data[["Fare"]].fillna(0),
                           Embarked
                           ], axis=1)

# 标签
labels = data["Survived"].values * 2 - 1

# 特征维数
dimension = features.shape[1]

# 嵌入向量维度
k = 2

# 一次项
x = ms.core.Variable(dim=(dimension, 1), init=False, trainable=False)

# 三个类别类特征的三套One-Hot
x_Pclass = ms.core.Variable(dim=(Pclass.shape[1], 1), init=False, trainable=False)
x_Sex = ms.core.Variable(dim=(Sex.shape[1], 1), init=False, trainable=False)
x_Embarked = ms.core.Variable(dim=(Embarked.shape[1], 1), init=False, trainable=False)


# 标签
label = ms.core.Variable(dim=(1, 1), init=False, trainable=False)

# 一次项权值向量
w = ms.core.Variable(dim=(1, dimension), init=True, trainable=True)

# 类别类特征的嵌入矩阵
E_Pclass = ms.core.Variable(dim=(k, Pclass.shape[1]), init=True, trainable=True)
E_Sex = ms.core.Variable(dim=(k, Sex.shape[1]), init=True, trainable=True)
E_Embarked = ms.core.Variable(dim=(k, Embarked.shape[1]), init=True, trainable=True)

# 偏置
b = ms.core.Variable(dim=(1, 1), init=True, trainable=True)


# Wide部分
wide = ms.ops.MatMul(w, x)


# Deep部分，三个嵌入向量
embedding_Pclass = ms.ops.MatMul(E_Pclass, x_Pclass)
embedding_Sex = ms.ops.MatMul(E_Sex, x_Sex)
embedding_Embarked = ms.ops.MatMul(E_Embarked, x_Embarked)

# 将三个嵌入向量连接在一起
embedding = ms.ops.Concat(
        embedding_Pclass,
        embedding_Sex,
        embedding_Embarked
        )

# 第一隐藏层
hidden_1 = ms.layer.fc(embedding, 3 * k, 8, "ReLU")

# 第二隐藏层
hidden_2 = ms.layer.fc(hidden_1, 8, 4, "ReLU")

# 输出层
deep = ms.layer.fc(hidden_2, 4, 1, None)

# 输出
output = ms.ops.Add(wide, deep, b)

# 预测概率
predict = ms.ops.Logistic(output)

# 损失函数
loss = ms.ops.loss.LogLoss(ms.ops.Multiply(label, output))

learning_rate = 0.005
optimizer = ms.optimizer.Adam(ms.default_graph, loss, learning_rate)
accuracy = ms.ops.metrics.Accuracy(output, label)
precision = ms.ops.metrics.Precision(output, label)
recall = ms.ops.metrics.Recall(output, label)
auc = ms.ops.metrics.ROC_AUC(output, label)
roc = ms.ops.metrics.ROC(output, label)

batch_size = 16

trainer = SimpleTrainer([x, x_Pclass, x_Sex, x_Embarked], label,
                        loss, optimizer, epoches=20, batch=16,eval_on_train=True,metrics_ops=[accuracy,precision,recall,roc,auc])
train_inputs = {
    x.name: features,
    x_Pclass.name: features[:, :3],
    x_Sex.name: features[:, 3:5],
    x_Embarked.name: features[:, 9:]
}

trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
# Out:
# [INIT] Variable weights init finished
# - Epoch [1] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.698491
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.694953
# -- iteration [299] finished, time cost: 0.12  and loss value: 1.580087
# -- iteration [399] finished, time cost: 0.12  and loss value: 0.806489
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.540618
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.254853
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.404885
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.412913
# - Epoch [1] train finished, time cost: 1.05
# Epoch [1] evaluation metrics Accuracy: 0.6162 Precision: 0.0000 Recall: 0.0000 ROC_AUC: 0.4214
# - Epoch [2] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.349381
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.457966
# -- iteration [299] finished, time cost: 0.12  and loss value: 2.827226
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.086304
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.411835
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.623578
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.285428
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.363933
# - Epoch [2] train finished, time cost: 1.01
# Epoch [2] evaluation metrics Accuracy: 0.6173 Precision: 0.6000 Recall: 0.0088 ROC_AUC: 0.5893
# - Epoch [3] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.349088
# -- iteration [199] finished, time cost: 0.12  and loss value: 0.451111
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.484332
# -- iteration [399] finished, time cost: 0.12  and loss value: 1.053108
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.405228
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.109694
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.278171
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.464944
# - Epoch [3] train finished, time cost: 1.04
# Epoch [3] evaluation metrics Accuracy: 0.6633 Precision: 0.6875 Recall: 0.2251 ROC_AUC: 0.6939
# - Epoch [4] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.13  and loss value: 0.457478
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.526102
# -- iteration [299] finished, time cost: 0.11  and loss value: 0.018384
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.939064
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.413267
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.719933
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.274362
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.542763
# - Epoch [4] train finished, time cost: 1.02
# Epoch [4] evaluation metrics Accuracy: 0.6869 Precision: 0.6886 Recall: 0.3363 ROC_AUC: 0.7104
# - Epoch [5] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.514609
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.568603
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.004332
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.905291
# -- iteration [499] finished, time cost: 0.15  and loss value: 0.391036
# -- iteration [599] finished, time cost: 0.11  and loss value: 0.659856
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.245580
# -- iteration [799] finished, time cost: 0.13  and loss value: 0.523194
# - Epoch [5] train finished, time cost: 1.08
# Epoch [5] evaluation metrics Accuracy: 0.6835 Precision: 0.6899 Recall: 0.3187 ROC_AUC: 0.7146
# - Epoch [6] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.475364
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.552953
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.006577
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.947725
# -- iteration [499] finished, time cost: 0.11  and loss value: 0.348985
# -- iteration [599] finished, time cost: 0.14  and loss value: 0.814824
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.208294
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.446115
# - Epoch [6] train finished, time cost: 1.06
# Epoch [6] evaluation metrics Accuracy: 0.6667 Precision: 0.6860 Recall: 0.2427 ROC_AUC: 0.7147
# - Epoch [7] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.396657
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.512057
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.024877
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.013014
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.311978
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.064810
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.184415
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.378999
# - Epoch [7] train finished, time cost: 1.03
# Epoch [7] evaluation metrics Accuracy: 0.6678 Precision: 0.8026 Recall: 0.1784 ROC_AUC: 0.7128
# - Epoch [8] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.11  and loss value: 0.342086
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.488079
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.082618
# -- iteration [399] finished, time cost: 0.11  and loss value: 1.036231
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.296794
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.224699
# -- iteration [699] finished, time cost: 0.11  and loss value: 0.184265
# -- iteration [799] finished, time cost: 0.12  and loss value: 0.357799
# - Epoch [8] train finished, time cost: 1.03
# Epoch [8] evaluation metrics Accuracy: 0.6566 Precision: 0.8103 Recall: 0.1374 ROC_AUC: 0.7235
# - Epoch [9] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.12  and loss value: 0.337901
# -- iteration [199] finished, time cost: 0.11  and loss value: 0.505586
# -- iteration [299] finished, time cost: 0.13  and loss value: 0.126019
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.981458
# -- iteration [499] finished, time cost: 0.12  and loss value: 0.307160
# -- iteration [599] finished, time cost: 0.11  and loss value: 1.174482
# -- iteration [699] finished, time cost: 0.12  and loss value: 0.208374
# -- iteration [799] finished, time cost: 0.15  and loss value: 0.385868
# - Epoch [9] train finished, time cost: 1.06
# Epoch [9] evaluation metrics Accuracy: 0.6655 Precision: 0.8333 Recall: 0.1608 ROC_AUC: 0.7517
# - Epoch [10] train start, batch size: 8, train data size: 4
# -- iteration [99] finished, time cost: 0.14  and loss value: 0.380749
# -- iteration [199] finished, time cost: 0.13  and loss value: 0.564521
# -- iteration [299] finished, time cost: 0.12  and loss value: 0.096275
# -- iteration [399] finished, time cost: 0.11  and loss value: 0.875123
# -- iteration [499] finished, time cost: 0.14  and loss value: 0.333139
# -- iteration [599] finished, time cost: 0.12  and loss value: 0.996988
# -- iteration [699] finished, time cost: 0.13  and loss value: 0.246471
# -- iteration [799] finished, time cost: 0.11  and loss value: 0.440755
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-64a59b0a6d51> in <module>
#     117 }
#     118
# --> 119 trainer.train_and_eval(train_inputs, labels, train_inputs, labels)
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/trainer/trainer.py in train_and_eval(self, train_x, train_y, test_x, test_y)
#      63
#      64         # 传入数据，开始主循环
# ---> 65         self.main_loop(train_x, train_y, test_x, test_y)
#      66
#      67     def main_loop(self, train_x, train_y, test_x, test_y):
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/trainer/trainer.py in main_loop(self, train_x, train_y, test_x, test_y)
#      74
#      75             # 模型训练
# ---> 76             self.train(train_x, train_y)
#      77
#      78             # 如果需要，对模型进行评估
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/trainer/trainer.py in train(self, train_x, train_y)
#      95
#      96             # 使用一个样本，执行一次前向传播和反向传播
# ---> 97             self.one_step(self._get_input_values(train_x, i), train_y[i])
#      98
#      99             if (i + 1) % self.print_iteration_interval == 0:
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/trainer/trainer.py in one_step(self, data_x, data_y, is_eval)
#     161         # 只有在训练阶段才执行优化器
#     162         if not is_eval:
# --> 163             self.optimizer.one_step()
#     164
#     165     @abc.abstractmethod
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/optimizer/optimizer.py in one_step(self)
#      36         计算并累加样本的梯度
#      37         """
# ---> 38         self.forward_backward()
#      39         self.acc_no += 1
#      40
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/optimizer/optimizer.py in forward_backward(self)
#      97
#      98         # 前向传播计算结果节点
# ---> 99         self.target.forward()
#     100
#     101         # 反向传播计算雅可比矩阵
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/core/node.py in forward(self)
#      53         for node in self.parents:
#      54             if node.value is None:
# ---> 55                 node.forward()
#      56
#      57         self.compute()
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/core/node.py in forward(self)
#      53         for node in self.parents:
#      54             if node.value is None:
# ---> 55                 node.forward()
#      56
#      57         self.compute()
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/core/node.py in forward(self)
#      53         for node in self.parents:
#      54             if node.value is None:
# ---> 55                 node.forward()
#      56
#      57         self.compute()
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/core/node.py in forward(self)
#      53         for node in self.parents:
#      54             if node.value is None:
# ---> 55                 node.forward()
#      56
#      57         self.compute()
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/core/node.py in forward(self)
#      55                 node.forward()
#      56
# ---> 57         self.compute()
#      58
#      59     def dimension(self):
#
# ~/Desktop/python/数据库/deeplearning-framework/HuichuanFlow/ops/ops.py in compute(self)
#      40         assert len(self.parents) == 2 and self.parents[0].shape()[
#      41             1] == self.parents[1].shape()[0]
# ---> 42         self.value = self.parents[0].value * self.parents[1].value
#      43
#      44     def get_jacobi(self, parent):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __mul__(self, other)
#     216         if isinstance(other, (N.ndarray, list, tuple)) :
#     217             # This promotes 1-D vectors to row vectors
# --> 218             return N.dot(self, asmatrix(other))
#     219         if isscalar(other) or not hasattr(other, '__rmul__') :
#     220             return N.dot(self, other)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/matrixlib/defmatrix.py in __array_finalize__(self, obj)
#     165         return ret
#     166
# --> 167     def __array_finalize__(self, obj):
#     168         self._getitem = False
#     169         if (isinstance(obj, matrix) and obj._getitem): return
#
# KeyboardInterrupt:
